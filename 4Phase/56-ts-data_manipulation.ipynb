# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Time-Series-Data" data-toc-modified-id="Time-Series-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Time Series Data</a></span></li><li><span><a href="#Objectives" data-toc-modified-id="Objectives-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#What-Are-Time-Series-Data?" data-toc-modified-id="What-Are-Time-Series-Data?-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>What Are Time Series Data?</a></span><ul class="toc-item"><li><span><a href="#Some-Examples" data-toc-modified-id="Some-Examples-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Some Examples</a></span></li><li><span><a href="#Uses-for-Time-Series" data-toc-modified-id="Uses-for-Time-Series-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Uses for Time Series</a></span></li><li><span><a href="#Example-Data" data-toc-modified-id="Example-Data-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Example Data</a></span></li></ul></li><li><span><a href="#Datetime-Objects" data-toc-modified-id="Datetime-Objects-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Datetime Objects</a></span><ul class="toc-item"><li><span><a href="#Setting-Datetime-Objects-as-the-Index" data-toc-modified-id="Setting-Datetime-Objects-as-the-Index-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Setting Datetime Objects as the Index</a></span></li><li><span><a href="#Investigating-Time-Series-with-Datetime-Objects" data-toc-modified-id="Investigating-Time-Series-with-Datetime-Objects-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Investigating Time Series with Datetime Objects</a></span></li></ul></li><li><span><a href="#Resampling-Techniques" data-toc-modified-id="Resampling-Techniques-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Resampling Techniques</a></span><ul class="toc-item"><li><span><a href="#Aside:-Deeper-Exploration" data-toc-modified-id="Aside:-Deeper-Exploration-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Aside: Deeper Exploration</a></span><ul class="toc-item"><li><span><a href="#.bfill(),-.ffill(),-and-.interpolate()" data-toc-modified-id=".bfill(),-.ffill(),-and-.interpolate()-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span><code>.bfill()</code>, <code>.ffill()</code>, and <code>.interpolate()</code></a></span></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Exercise</a></span></li></ul></li></ul></li><li><span><a href="#Visualizing-Time-Series" data-toc-modified-id="Visualizing-Time-Series-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Visualizing Time Series</a></span><ul class="toc-item"><li><span><a href="#Showing-Changes-Over-Time" data-toc-modified-id="Showing-Changes-Over-Time-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Showing Changes Over Time</a></span><ul class="toc-item"><li><span><a href="#Line-Plot" data-toc-modified-id="Line-Plot-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Line Plot</a></span></li><li><span><a href="#Dot-Plot" data-toc-modified-id="Dot-Plot-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Dot Plot</a></span></li><li><span><a href="#Grouping-Plots" data-toc-modified-id="Grouping-Plots-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Grouping Plots</a></span><ul class="toc-item"><li><span><a href="#All-Annual-Separated" data-toc-modified-id="All-Annual-Separated-6.1.3.1"><span class="toc-item-num">6.1.3.1&nbsp;&nbsp;</span>All Annual Separated</a></span></li><li><span><a href="#All-Annual-Together" data-toc-modified-id="All-Annual-Together-6.1.3.2"><span class="toc-item-num">6.1.3.2&nbsp;&nbsp;</span>All Annual Together</a></span></li></ul></li></ul></li><li><span><a href="#Showing-Distributions" data-toc-modified-id="Showing-Distributions-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Showing Distributions</a></span><ul class="toc-item"><li><span><a href="#Histogram" data-toc-modified-id="Histogram-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Histogram</a></span></li><li><span><a href="#Density" data-toc-modified-id="Density-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Density</a></span></li><li><span><a href="#Box-Plot" data-toc-modified-id="Box-Plot-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Box Plot</a></span></li><li><span><a href="#Heat-Maps" data-toc-modified-id="Heat-Maps-6.2.4"><span class="toc-item-num">6.2.4&nbsp;&nbsp;</span>Heat Maps</a></span><ul class="toc-item"><li><span><a href="#Example-of-how-heat-maps-are-useful" data-toc-modified-id="Example-of-how-heat-maps-are-useful-6.2.4.1"><span class="toc-item-num">6.2.4.1&nbsp;&nbsp;</span>Example of how heat maps are useful</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Level-Up:-More-EDA" data-toc-modified-id="Level-Up:-More-EDA-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Level Up: More EDA</a></span></li></ul></div>

# %% [markdown]
# # Time Series Data

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 1000)
from datetime import datetime as dt

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %% [markdown]
# #  Objectives

# %% [markdown]
# - Understand the use case for time series data
# - Manipulate datetime objects
# - Understand different resampling techniques
# - Implement different visualization techniques for time series data

# %% [markdown]
# # What Are Time Series Data?

# %% [markdown]
# > We can say data is a **time series** when the temporal information is a key focus of the data.

# %% [markdown]
# Data in a time series can stem from historical data or data that is dependent on past values.

# %% [markdown]
# ## Some Examples

# %% [markdown]
# - Stock prices
# - Atmospheric changes over the course of decades
# - Audio samples
# - Heart rate data

# %% [markdown]
# ## Uses for Time Series

# %% [markdown]
# - Understand some underlying process
# - Forecasting (what we'll mostly focus on)
# - Imputation (filling missing "past" data)
# - Anomaly detection

# %% [markdown]
# ## Example Data

# %% [markdown]
# This data comes from [Google Trends](https://trends.google.com). Try entering a search term! The little question-mark icon on the new page explains how to interpret the numbers.

# %%
# Define a function that will help us load and
# clean up a dataset.

def load_trend(trend_name='football', country_code='us'):
    df = pd.read_csv('data/google-trends_'
                     + trend_name + '_'
                     + country_code
                     + '.csv').iloc[1:, :]
    df.columns = ['counts']
    df['counts'] = df['counts'].str.replace('<1', '0').astype(int)
    return df

# %%
df = load_trend(**{'trend_name': 'data-science', 'country_code': 'us'})
df.head()
# Out:
#          counts
# 2004-01      17
# 2004-02       5
# 2004-03      11
# 2004-04      10
# 2004-05       8

# %% [markdown]
# Now we can do this with multiple time series data!

# %%
trends = [
    {'trend_name': 'data-science', 'country_code': 'us'},
    {'trend_name': 'football', 'country_code': 'us'},
    {'trend_name': 'football', 'country_code': 'uk'},
    {'trend_name': 'coronavirus', 'country_code': 'us'},
    {'trend_name': 'trump', 'country_code': 'us'},
    {'trend_name': 'taxes', 'country_code': 'us'},
    {'trend_name': 'avengers', 'country_code': 'us'}
]

# %%
trend_dfs = [load_trend(**trend) for trend in trends]

# %%
fig, ax = plt.subplots()

ax.plot(df.index, df['counts']);

# %%
# Let's see if we can guess which is which just by looking
# at their graphs.

fig, axs = plt.subplots(len(trend_dfs), 1, figsize=(8, 10))
plt.tight_layout()
for i, trend_df in enumerate(trend_dfs):
    ax = axs[i]
#     ax.set_title(str(trends[i]))
    ax.plot(np.array(trend_df.index), trend_df['counts'])
    ticks = ax.get_xticks()
    ax.set_ylim((0, 100))
    ax.set_xticks([tick for tick in ticks if tick%24 == 0])

# %% [markdown]
# # Datetime Objects

# %% [markdown]
# Datetime objects make our time series modeling lives easier.  They will allow us to perform essential data prep tasks with a few lines of code.
#
# We need our time series **index** to be datetime objects, since our models will rely on being able to identify the previous chronological value.

# %% [markdown]
# There is a `datetime` [library](https://docs.python.org/2/library/datetime.html), and inside `pandas` there is a datetime module as well as a to_datetime() function.
#
# For time series modeling, the first step often is to make sure that the index is a datetime object.

# %% [markdown]
# ## Setting Datetime Objects as the Index

# %% [markdown]
# There are a few ways to **reindex** our series to datetime.
#
# We can use `pandas.to_datetime()` method:

# %% [markdown]
# Our data for this lesson comes from the a dataset you can find on Kaggle [here](https://www.kaggle.com/datasets/jyotiprasadpal/historical-sales-data-on-daily-basis-of-a-company). It lists sales data for a European company.

# %%
ts_no_datetime = pd.read_csv('data/Historical_Data.csv')

# %%
ts_no_datetime.head()
# Out:
#        Date  Article_ID Country_Code  Sold_Units
# 0  20170817        1132           AT           1
# 1  20170818        1132           AT           1
# 2  20170821        1132           AT           1
# 3  20170822        1132           AT           1
# 4  20170906        1132           AT           1

# %%
ts_no_datetime['Country_Code'].unique()
# Out:
# array(['AT', 'FI', 'FR', 'SE'], dtype=object)

# %% [markdown]
# These countries are Austria, Finland, France, and Sweden.

# %% [markdown]
# There are [many](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior) different date and time format codes.

# %%
# Create and set
ts = ts_no_datetime.set_index(pd.to_datetime(ts_no_datetime['Date']), drop=True)

# %% [markdown]
# > Alternatively, we can parse the dates directly on import

# %%
# Set at file import
ts = pd.read_csv('data/Gun_Crimes_Heat_Map.csv', index_col='Date', parse_dates=True)

# %%
print(f'Now our index is a {type(ts.index)}')
# Out:
# Now our index is a <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
ts.head()
# Out:
#                           ID Case Number                Block  IUCR  \
# Date
# 2014-01-01 00:02:00  9446834    HX100098    072XX S MORGAN ST  1477
# 2014-01-01 00:03:00  9446765    HX100013  064XX S ROCKWELL ST  143A
# 2014-01-01 00:04:00  9446921    HX100067  048XX S PRAIRIE AVE  1460
# 2014-01-01 00:05:00  9446783    HX100093      011XX W 50TH ST  143A
# 2014-01-01 00:05:00  9446811    HX100017    031XX W WALNUT ST  143A
#
#                           Primary Type                     Description  \
# Date
# 2014-01-01 00:02:00  WEAPONS VIOLATION      RECKLESS FIREARM DISCHARGE
# 2014-01-01 00:03:00  WEAPONS VIOLATION        UNLAWFUL POSS OF HANDGUN
# 2014-01-01 00:04:00  WEAPONS VIOLATION  POSS FIREARM/AMMO:NO FOID CARD
# 2014-01-01 00:05:00  WEAPONS VIOLATION        UNLAWFUL POSS OF HANDGUN
# 2014-01-01 00:05:00  WEAPONS VIOLATION        UNLAWFUL POSS OF HANDGUN
#
#                                Location Description  Arrest  Domestic  Beat  \
# Date
# 2014-01-01 00:02:00   RESIDENTIAL YARD (FRONT/BACK)    True     False   733
# 2014-01-01 00:03:00   RESIDENTIAL YARD (FRONT/BACK)    True     False   825
# 2014-01-01 00:04:00                       APARTMENT    True     False   224
# 2014-01-01 00:05:00  PARKING LOT/GARAGE(NON.RESID.)    True     False   933
# 2014-01-01 00:05:00         RESIDENCE PORCH/HALLWAY    True     False  1222
#
#                      ...  Ward  Community Area  FBI Code X Coordinate  \
# Date                 ...
# 2014-01-01 00:02:00  ...  17.0              68        15    1170897.0
# 2014-01-01 00:03:00  ...  15.0              66        15    1160145.0
# 2014-01-01 00:04:00  ...   3.0              38        15    1178859.0
# 2014-01-01 00:05:00  ...  16.0              61        15    1169689.0
# 2014-01-01 00:05:00  ...  27.0              27        15    1155344.0
#
#                      Y Coordinate  Year              Updated On   Latitude  \
# Date
# 2014-01-01 00:02:00     1856795.0  2014  02/10/2018 03:50:01 PM  41.762519
# 2014-01-01 00:03:00     1861909.0  2014  02/10/2018 03:50:01 PM  41.776780
# 2014-01-01 00:04:00     1872997.0  2014  02/04/2016 06:33:39 AM  41.806801
# 2014-01-01 00:05:00     1871646.0  2014  02/10/2018 03:50:01 PM  41.803298
# 2014-01-01 00:05:00     1901461.0  2014  02/10/2018 03:50:01 PM  41.885414
#
#                      Longitude                       Location
# Date
# 2014-01-01 00:02:00 -87.649198   (41.762519013, -87.64919809)
# 2014-01-01 00:03:00 -87.688465  (41.776780469, -87.688465418)
# 2014-01-01 00:04:00 -87.619523   (41.806801421, -87.61952336)
# 2014-01-01 00:05:00 -87.653195    (41.8032982, -87.653195042)
# 2014-01-01 00:05:00 -87.705005  (41.885413516, -87.705005317)
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Investigating Time Series with Datetime Objects

# %% [markdown]
# Datetime objects include aspects of the date as attributes, like month and year:

# %%
# Entire
ts.index[0]
# Out:
# Timestamp('2014-01-01 00:02:00')

# %%
# Day
ts.index[0].day
# Out:
# 1

# %%
# Month
ts.index[0].month
# Out:
# 1

# %%
# Year
ts.index[0].year
# Out:
# 2014

# %%
# Sort and reset index
# |||

# %% [markdown]
# We can also use the date to directly slice the DataFrame

# %%
# Only data after 2019
ts['2021':]
# Out:
#                            ID Case Number                   Block  IUCR  \
# Date
# 2021-01-01 00:00:00  12258861    JE100369      016XX N CICERO AVE  051A
# 2021-01-01 00:00:00  12259020    JE100698    075XX S JEFFERY BLVD  141B
# 2021-01-01 00:00:00  12259663    JE101362   040XX S LAKE PARK AVE  141B
# 2021-01-01 00:03:00  12258570    JE100122  057XX S MARSHFIELD AVE  143B
# 2021-01-01 00:05:00  12258631    JE100007   064XX N CLAREMONT AVE  143A
# ...                       ...         ...                     ...   ...
# 2021-02-11 21:56:00  12291334    JE139290         015XX E 73RD ST  041A
# 2021-02-11 21:56:00  12291244    JE139274      059XX W MADISON ST  143A
# 2021-02-11 22:16:00  12291306    JE139291      004XX S KEDZIE AVE  143A
# 2021-02-11 22:55:00  12291295    JE139305   099XX S VINCENNES AVE  143A
# 2021-02-11 23:30:00  12293080    JE141688   010XX N FRANCISCO AVE  031A
#
#                           Primary Type                          Description  \
# Date
# 2021-01-01 00:00:00            ASSAULT                 AGGRAVATED - HANDGUN
# 2021-01-01 00:00:00  WEAPONS VIOLATION         UNLAWFUL USE - OTHER FIREARM
# 2021-01-01 00:00:00  WEAPONS VIOLATION         UNLAWFUL USE - OTHER FIREARM
# 2021-01-01 00:03:00  WEAPONS VIOLATION  UNLAWFUL POSSESSION - OTHER FIREARM
# 2021-01-01 00:05:00  WEAPONS VIOLATION        UNLAWFUL POSSESSION - HANDGUN
# ...                                ...                                  ...
# 2021-02-11 21:56:00            BATTERY                 AGGRAVATED - HANDGUN
# 2021-02-11 21:56:00  WEAPONS VIOLATION        UNLAWFUL POSSESSION - HANDGUN
# 2021-02-11 22:16:00  WEAPONS VIOLATION        UNLAWFUL POSSESSION - HANDGUN
# 2021-02-11 22:55:00  WEAPONS VIOLATION        UNLAWFUL POSSESSION - HANDGUN
# 2021-02-11 23:30:00            ROBBERY                      ARMED - HANDGUN
#
#                                 Location Description  Arrest  Domestic  Beat  \
# Date
# 2021-01-01 00:00:00                            ALLEY   False     False  2533
# 2021-01-01 00:00:00                           STREET   False     False   414
# 2021-01-01 00:00:00                            ALLEY   False     False   214
# 2021-01-01 00:03:00  RESIDENCE - YARD (FRONT / BACK)   False     False   715
# 2021-01-01 00:05:00                            ALLEY    True     False  2412
# ...                                              ...     ...       ...   ...
# 2021-02-11 21:56:00                           STREET   False     False   324
# 2021-02-11 21:56:00                       RESTAURANT    True     False  1513
# 2021-02-11 22:16:00                           STREET    True     False  1134
# 2021-02-11 22:55:00                      GAS STATION    True     False  2213
# 2021-02-11 23:30:00                           STREET   False     False  1211
#
#                      ...  Ward  Community Area  FBI Code X Coordinate  \
# Date                 ...
# 2021-01-01 00:00:00  ...  37.0              25       04A    1144145.0
# 2021-01-01 00:00:00  ...   8.0              43        15    1190847.0
# 2021-01-01 00:00:00  ...   4.0              36        15    1183760.0
# 2021-01-01 00:03:00  ...  16.0              67        15    1166325.0
# 2021-01-01 00:05:00  ...  50.0               2        15    1159480.0
# ...                  ...   ...             ...       ...          ...
# 2021-02-11 21:56:00  ...   7.0              43       04B          NaN
# 2021-02-11 21:56:00  ...  29.0              25        15          NaN
# 2021-02-11 22:16:00  ...  28.0              27        15          NaN
# 2021-02-11 22:55:00  ...  34.0              73        15          NaN
# 2021-02-11 23:30:00  ...  26.0              24        03          NaN
#
#                      Y Coordinate  Year              Updated On   Latitude  \
# Date
# 2021-01-01 00:00:00     1910673.0  2021  01/16/2021 03:49:23 PM  41.910910
# 2021-01-01 00:00:00     1855361.0  2021  01/16/2021 03:49:23 PM  41.758125
# 2021-01-01 00:00:00     1878197.0  2021  01/16/2021 03:49:23 PM  41.820957
# 2021-01-01 00:03:00     1866554.0  2021  01/16/2021 03:49:23 PM  41.789398
# 2021-01-01 00:05:00     1942629.0  2021  01/16/2021 03:49:23 PM  41.998297
# ...                           ...   ...                     ...        ...
# 2021-02-11 21:56:00           NaN  2021  02/18/2021 03:52:19 PM        NaN
# 2021-02-11 21:56:00           NaN  2021  02/18/2021 03:52:19 PM        NaN
# 2021-02-11 22:16:00           NaN  2021  02/18/2021 03:52:19 PM        NaN
# 2021-02-11 22:55:00           NaN  2021  02/18/2021 03:52:19 PM        NaN
# 2021-02-11 23:30:00           NaN  2021  02/18/2021 03:52:19 PM        NaN
#
#                      Longitude                       Location
# Date
# 2021-01-01 00:00:00 -87.745899  (41.910909931, -87.745898897)
# 2021-01-01 00:00:00 -87.576126  (41.758125331, -87.576125553)
# 2021-01-01 00:00:00 -87.601386  (41.820957498, -87.601385842)
# 2021-01-01 00:03:00 -87.665677  (41.789397529, -87.665677479)
# 2021-01-01 00:05:00 -87.688680  (41.998296976, -87.688680214)
# ...                        ...                            ...
# 2021-02-11 21:56:00        NaN                            NaN
# 2021-02-11 21:56:00        NaN                            NaN
# 2021-02-11 22:16:00        NaN                            NaN
# 2021-02-11 22:55:00        NaN                            NaN
# 2021-02-11 23:30:00        NaN                            NaN
#
# [1802 rows x 21 columns]

# %%
# Only data from this time period
ts['2010-02-01 00:00':'2011-02-01 01:00']
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# We can easily see now whether more products are sold, for example, during winter months. For simplicity we'll say that winter comprises the months of January, February, and March.

# %%
ts['month'] = ts.index

# %%
ts['month'] = ts['month'].apply(lambda x: x.month)

# %%
ts['winter'] = ts['month'].apply(lambda x: 1 <= x <= 3)

# %%
fig, ax = plt.subplots()

sum_ratio = ts['winter'].value_counts()[1]/len(ts)

x = ts['winter'].value_counts().index
y = ts['winter'].value_counts()
sns.barplot(x=x, y=y)

ax.set_title(f'{sum_ratio: 0.2%} of Sales Happen in Winter');

# %% [markdown]
# # Resampling Techniques

# %% [markdown]
# > **Resampling** allows us to convert the time series into a particular frequency
#
# [`.resample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) docs.
#
# [Resampling](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#resampling) User Guide.

# %% [markdown]
# With a Datetime index, we also have new abilities, such as **resampling**.
#
# To create our timeseries, we will count the number of sales reported per week.

# %% [markdown]
# There are many possible units for resampling, each with its own alias:

# %%
ts.resample('D')

# %% [markdown]
# <table style="display: inline-block">
#     <caption style="text-align: center"><strong>TIME SERIES OFFSET ALIASES</strong></caption>
# <tr><th>ALIAS</th><th>DESCRIPTION</th></tr>
# <tr><td>B</td><td>business day frequency</td></tr>
# <tr><td>C</td><td>custom business day frequency (experimental)</td></tr>
# <tr><td>D</td><td>calendar day frequency</td></tr>
# <tr><td>W</td><td>weekly frequency</td></tr>
# <tr><td>M</td><td>month end frequency</td></tr>
# <tr><td>SM</td><td>semi-month end frequency (15th and end of month)</td></tr>
# <tr><td>BM</td><td>business month end frequency</td></tr>
# <tr><td>CBM</td><td>custom business month end frequency</td></tr>
# <tr><td>MS</td><td>month start frequency</td></tr>
# <tr><td>SMS</td><td>semi-month start frequency (1st and 15th)</td></tr>
# <tr><td>BMS</td><td>business month start frequency</td></tr>
# <tr><td>CBMS</td><td>custom business month start frequency</td></tr>
# <tr><td>Q</td><td>quarter end frequency</td></tr>
# <tr><td></td><td><font color=white>intentionally left blank</font></td></tr></table>
#
# <table style="display: inline-block; margin-left: 40px">
# <caption style="text-align: center"></caption>
# <tr><th>ALIAS</th><th>DESCRIPTION</th></tr>
# <tr><td>BQ</td><td>business quarter endfrequency</td></tr>
# <tr><td>QS</td><td>quarter start frequency</td></tr>
# <tr><td>BQS</td><td>business quarter start frequency</td></tr>
# <tr><td>A</td><td>year end frequency</td></tr>
# <tr><td>BA</td><td>business year end frequency</td></tr>
# <tr><td>AS</td><td>year start frequency</td></tr>
# <tr><td>BAS</td><td>business year start frequency</td></tr>
# <tr><td>BH</td><td>business hour frequency</td></tr>
# <tr><td>H</td><td>hourly frequency</td></tr>
# <tr><td>T, min</td><td>minutely frequency</td></tr>
# <tr><td>S</td><td>secondly frequency</td></tr>
# <tr><td>L, ms</td><td>milliseconds</td></tr>
# <tr><td>U, us</td><td>microseconds</td></tr>
# <tr><td>N</td><td>nanoseconds</td></tr></table>

# %% [markdown]
# When resampling, we have to provide a rule to resample by, and an **aggregate function**.

# %% [markdown]
# **To upsample** is to increase the frequency of the data of interest.
# **To downsample** is to decrease the frequency of the data of interest.
#
# For our purposes, we will downsample, and  count the number of occurences per day.

# %%
# Weekly Resample
ts.resample('W').count()
# Out:
#              ID  Case Number  Block  IUCR  Primary Type  Description  \
# Date
# 2014-01-05  156          156    156   156           156          156
# 2014-01-12  133          133    133   133           133          133
# 2014-01-19  172          172    172   172           172          172
# 2014-01-26  172          172    172   172           172          172
# 2014-02-02  156          156    156   156           156          156
# 2014-02-09  120          120    120   120           120          120
# 2014-02-16  113          113    113   113           113          113
# 2014-02-23  104          104    104   104           104          104
# 2014-03-02  117          117    117   117           117          117
# 2014-03-09  131          131    131   131           131          131
# 2014-03-16  146          146    146   146           146          146
# 2014-03-23  166          166    166   166           166          166
# 2014-03-30  132          132    132   132           132          132
# 2014-04-06  171          171    171   171           171          171
# 2014-04-13  221          221    221   221           221          221
# 2014-04-20  215          215    215   215           215          215
# 2014-04-27  215          215    215   215           215          215
# 2014-05-04  208          208    208   208           208          208
# 2014-05-11  218          218    218   218           218          218
# 2014-05-18  222          222    222   222           222          222
# 2014-05-25  218          218    218   218           218          218
# 2014-06-01  218          218    218   218           218          218
# 2014-06-08  206          206    206   206           206          206
# 2014-06-15  231          231    231   231           231          231
# 2014-06-22  234          234    234   234           234          234
# 2014-06-29  235          235    235   235           235          235
# 2014-07-06  249          249    249   249           249          249
# 2014-07-13  233          233    233   233           233          233
# 2014-07-20  220          220    220   220           220          220
# 2014-07-27  224          224    224   224           224          224
# 2014-08-03  227          227    227   227           227          227
# 2014-08-10  201          201    201   201           201          201
# 2014-08-17  221          221    221   221           221          221
# 2014-08-24  206          206    206   206           206          206
# 2014-08-31  205          205    205   205           205          205
# 2014-09-07  176          176    176   176           176          176
# 2014-09-14  170          170    170   170           170          170
# 2014-09-21  203          203    203   203           203          203
# 2014-09-28  256          256    256   256           256          256
# 2014-10-05  212          212    212   212           212          212
# 2014-10-12  164          164    164   164           164          164
# 2014-10-19  196          196    196   196           196          196
# 2014-10-26  230          230    230   230           230          230
# 2014-11-02  224          224    224   224           224          224
# 2014-11-09  174          174    174   174           174          174
# 2014-11-16  190          190    190   190           190          190
# 2014-11-23  179          179    179   179           179          179
# 2014-11-30  177          177    177   177           177          177
# 2014-12-07  201          201    201   201           201          201
# 2014-12-14  228          228    228   228           228          228
# 2014-12-21  238          238    238   238           238          238
# 2014-12-28  217          217    217   217           217          217
# 2015-01-04  192          192    192   192           192          192
# 2015-01-11  144          144    144   144           144          144
# 2015-01-18  175          175    175   175           175          175
# 2015-01-25  217          217    217   217           217          217
# 2015-02-01  154          154    154   154           154          154
# 2015-02-08  128          128    128   128           128          128
# 2015-02-15  118          118    118   118           118          118
# 2015-02-22  123          123    123   123           123          123
# 2015-03-01  143          143    143   143           143          143
# 2015-03-08  172          172    172   172           172          172
# 2015-03-15  206          206    206   206           206          206
# 2015-03-22  199          199    199   199           199          199
# 2015-03-29  181          181    181   181           181          181
# 2015-04-05  218          218    218   218           218          218
# 2015-04-12  209          209    209   209           209          209
# 2015-04-19  207          207    207   207           207          207
# 2015-04-26  202          202    202   202           202          202
# 2015-05-03  193          193    193   193           193          193
# 2015-05-10  179          179    179   179           179          179
# 2015-05-17  256          256    256   256           256          256
# 2015-05-24  242          242    242   242           242          242
# 2015-05-31  232          232    232   232           232          232
# 2015-06-07  202          202    202   202           202          202
# 2015-06-14  230          230    230   230           230          230
# 2015-06-21  238          238    238   238           238          238
# 2015-06-28  237          237    237   237           237          237
# 2015-07-05  253          253    253   253           253          253
# 2015-07-12  227          227    227   227           227          227
# 2015-07-19  238          238    238   238           238          238
# 2015-07-26  268          268    268   268           268          268
# 2015-08-02  284          284    284   284           284          284
# 2015-08-09  247          247    247   247           247          247
# 2015-08-16  238          238    238   238           238          238
# 2015-08-23  261          261    261   261           261          261
# 2015-08-30  250          250    250   250           250          250
# 2015-09-06  260          260    260   260           260          260
# 2015-09-13  226          226    226   226           226          226
# 2015-09-20  247          247    247   247           247          247
# 2015-09-27  275          275    275   275           275          275
# 2015-10-04  236          236    236   236           236          236
# 2015-10-11  218          218    218   218           218          218
# 2015-10-18  203          203    203   203           203          203
# 2015-10-25  266          266    266   266           266          266
# 2015-11-01  232          232    232   232           232          232
# 2015-11-08  195          195    195   195           195          195
# 2015-11-15  212          212    212   212           212          212
# 2015-11-22  185          185    185   185           185          185
# 2015-11-29  201          201    201   201           201          201
# 2015-12-06  207          207    207   207           207          207
# 2015-12-13  199          199    199   199           199          199
# 2015-12-20  216          216    216   216           216          216
# 2015-12-27  236          236    236   236           236          236
# 2016-01-03  224          224    224   224           224          224
# 2016-01-10  253          253    253   253           253          253
# 2016-01-17  215          215    215   215           215          215
# 2016-01-24  226          226    226   226           226          226
# 2016-01-31  250          250    250   250           250          250
# 2016-02-07  208          208    208   208           208          208
# 2016-02-14  162          162    162   162           162          162
# 2016-02-21  190          190    190   190           190          190
# 2016-02-28  194          194    194   194           194          194
# 2016-03-06  182          182    182   182           182          182
# 2016-03-13  255          255    255   255           255          255
# 2016-03-20  236          236    236   236           236          236
# 2016-03-27  239          239    239   239           239          239
# 2016-04-03  257          257    257   257           257          257
# 2016-04-10  212          212    212   212           212          212
# 2016-04-17  292          292    292   292           292          292
# 2016-04-24  273          273    273   273           273          273
# 2016-05-01  230          230    230   230           230          230
# 2016-05-08  293          293    293   293           293          293
# 2016-05-15  247          247    247   247           247          247
# 2016-05-22  316          316    316   316           316          316
# 2016-05-29  313          313    313   313           313          313
# 2016-06-05  308          308    308   308           308          308
# 2016-06-12  282          282    282   282           282          282
# 2016-06-19  304          304    304   304           304          304
# 2016-06-26  298          298    298   298           298          298
# 2016-07-03  297          297    297   297           297          297
# 2016-07-10  349          349    349   349           349          349
# 2016-07-17  290          290    290   290           290          290
# 2016-07-24  286          286    286   286           286          286
# 2016-07-31  316          316    316   316           316          316
# 2016-08-07  323          323    323   323           323          323
# 2016-08-14  326          326    326   326           326          326
# 2016-08-21  327          327    327   327           327          327
# 2016-08-28  352          352    352   352           352          352
# 2016-09-04  336          336    336   336           336          336
# 2016-09-11  294          294    294   294           294          294
# 2016-09-18  285          285    285   285           285          285
# 2016-09-25  299          299    299   299           299          299
# 2016-10-02  253          253    253   253           253          253
# 2016-10-09  279          279    279   279           279          279
# 2016-10-16  326          326    326   326           326          326
# 2016-10-23  311          311    311   311           311          311
# 2016-10-30  292          292    292   292           292          292
# 2016-11-06  363          363    363   363           363          363
# 2016-11-13  309          309    309   309           309          309
# 2016-11-20  278          278    278   278           278          278
# 2016-11-27  298          298    298   298           298          298
# 2016-12-04  281          281    281   281           281          281
# 2016-12-11  225          225    225   225           225          225
# 2016-12-18  218          218    218   218           218          218
# 2016-12-25  264          264    264   264           264          264
# 2017-01-01  349          349    349   349           349          349
# 2017-01-08  254          254    254   254           254          254
# 2017-01-15  277          277    277   277           277          277
# 2017-01-22  304          304    304   304           304          304
# 2017-01-29  264          264    264   264           264          264
# 2017-02-05  283          283    283   283           283          283
# 2017-02-12  258          258    258   258           258          258
# 2017-02-19  279          279    279   279           279          279
# 2017-02-26  211          211    211   211           211          211
# 2017-03-05  211          211    211   211           211          211
# 2017-03-12  209          209    209   209           209          209
# 2017-03-19  202          202    202   202           202          202
# 2017-03-26  258          258    258   258           258          258
# 2017-04-02  229          229    229   229           229          229
# 2017-04-09  229          229    229   229           229          229
# 2017-04-16  335          335    335   335           335          335
# 2017-04-23  305          305    305   305           305          305
# 2017-04-30  274          274    274   274           274          274
# 2017-05-07  246          246    246   246           246          246
# 2017-05-14  256          256    256   256           256          256
# 2017-05-21  296          296    296   296           296          296
# 2017-05-28  303          303    303   303           303          303
# 2017-06-04  317          317    317   317           317          317
# 2017-06-11  318          318    318   318           318          318
# 2017-06-18  265          265    265   265           265          265
# 2017-06-25  298          298    298   298           298          298
# 2017-07-02  322          322    322   322           322          322
# 2017-07-09  378          378    378   378           378          378
# 2017-07-16  302          302    302   302           302          302
# 2017-07-23  309          309    309   309           309          309
# 2017-07-30  301          301    301   301           301          301
# 2017-08-06  285          285    285   285           285          285
# 2017-08-13  289          289    289   289           289          289
# 2017-08-20  321          321    321   321           321          321
# 2017-08-27  316          316    316   316           316          316
# 2017-09-03  353          353    353   353           353          353
# 2017-09-10  296          296    296   296           296          296
# 2017-09-17  267          267    267   267           267          267
# 2017-09-24  306          306    306   306           306          306
# 2017-10-01  287          287    287   287           287          287
# 2017-10-08  282          282    282   282           282          282
# 2017-10-15  273          273    273   273           273          273
# 2017-10-22  296          296    296   296           296          296
# 2017-10-29  309          309    309   309           309          309
# 2017-11-05  299          299    299   299           299          299
# 2017-11-12  289          289    289   289           289          289
# 2017-11-19  263          263    263   263           263          263
# 2017-11-26  273          273    273   273           273          273
# 2017-12-03  291          291    291   291           291          291
# 2017-12-10  275          275    275   275           275          275
# 2017-12-17  266          266    266   266           266          266
# 2017-12-24  267          267    267   267           267          267
# 2017-12-31  222          222    222   222           222          222
# 2018-01-07  283          283    283   283           283          283
# 2018-01-14  266          266    266   266           266          266
# 2018-01-21  247          247    247   247           247          247
# 2018-01-28  276          276    276   276           276          276
# 2018-02-04  213          213    213   213           213          213
# 2018-02-11  166          166    166   166           166          166
# 2018-02-18  217          217    217   217           217          217
# 2018-02-25  242          242    242   242           242          242
# 2018-03-04  224          224    224   224           224          224
# 2018-03-11  238          238    238   238           238          238
# 2018-03-18  227          227    227   227           227          227
# 2018-03-25  235          235    235   235           235          235
# 2018-04-01  237          237    237   237           237          237
# 2018-04-08  193          193    193   193           193          193
# 2018-04-15  276          276    276   276           276          276
# 2018-04-22  245          245    245   245           245          245
# 2018-04-29  260          260    260   260           260          260
# 2018-05-06  307          307    307   307           307          307
# 2018-05-13  276          276    276   276           276          276
# 2018-05-20  295          295    295   295           295          295
# 2018-05-27  344          344    344   344           344          344
# 2018-06-03  312          312    312   312           312          312
# 2018-06-10  313          313    313   313           313          313
# 2018-06-17  305          305    305   305           305          305
# 2018-06-24  268          268    268   268           268          268
# 2018-07-01  354          354    354   354           354          354
# 2018-07-08  333          333    333   333           333          333
# 2018-07-15  302          302    302   302           302          302
# 2018-07-22  294          294    294   294           294          294
# 2018-07-29  323          323    323   323           323          323
# 2018-08-05  328          328    328   328           328          328
# 2018-08-12  325          325    325   325           325          325
# 2018-08-19  321          321    321   321           321          321
# 2018-08-26  268          268    268   268           268          268
# 2018-09-02  322          322    322   322           322          322
# 2018-09-09  268          268    268   268           268          268
# 2018-09-16  268          268    268   268           268          268
# 2018-09-23  287          287    287   287           287          287
# 2018-09-30  251          251    251   251           251          251
# 2018-10-07  253          253    253   253           253          253
# 2018-10-14  264          264    264   264           264          264
# 2018-10-21  235          235    235   235           235          235
# 2018-10-28  288          288    288   288           288          288
# 2018-11-04  275          275    275   275           275          275
# 2018-11-11  258          258    258   258           258          258
# 2018-11-18  232          232    232   232           232          232
# 2018-11-25  228          228    228   228           228          228
# 2018-12-02  241          241    241   241           241          241
# 2018-12-09  256          256    256   256           256          256
# 2018-12-16  250          250    250   250           250          250
# 2018-12-23  256          256    256   256           256          256
# 2018-12-30  289          289    289   289           289          289
# 2019-01-06  328          328    328   328           328          328
# 2019-01-13  222          222    222   222           222          222
# 2019-01-20  240          240    240   240           240          240
# 2019-01-27  208          208    208   208           208          208
# 2019-02-03  172          172    172   172           172          172
# 2019-02-10  195          195    195   195           195          195
# 2019-02-17  215          215    215   215           215          215
# 2019-02-24  216          216    216   216           216          216
# 2019-03-03  201          201    201   201           201          201
# 2019-03-10  195          195    195   195           195          195
# 2019-03-17  219          219    219   219           219          219
# 2019-03-24  236          236    236   236           236          236
# 2019-03-31  256          256    256   256           256          256
# 2019-04-07  249          249    249   249           249          249
# 2019-04-14  244          244    244   244           244          244
# 2019-04-21  275          275    275   275           275          275
# 2019-04-28  288          288    288   288           288          288
# 2019-05-05  254          254    254   254           254          254
# 2019-05-12  238          238    238   238           238          238
# 2019-05-19  262          262    262   262           262          262
# 2019-05-26  346          346    346   346           346          346
# 2019-06-02  288          288    288   288           288          288
# 2019-06-09  321          321    321   321           321          321
# 2019-06-16  270          270    270   270           270          270
# 2019-06-23  259          259    259   259           259          259
# 2019-06-30  347          347    347   347           347          347
# 2019-07-07  351          351    351   351           351          351
# 2019-07-14  280          280    280   280           280          280
# 2019-07-21  317          317    317   317           317          317
# 2019-07-28  312          312    312   312           312          312
# 2019-08-04  335          335    335   335           335          335
# 2019-08-11  354          354    354   354           354          354
# 2019-08-18  300          300    300   300           300          300
# 2019-08-25  280          280    280   280           280          280
# 2019-09-01  280          280    280   280           280          280
# 2019-09-08  251          251    251   251           251          251
# 2019-09-15  297          297    297   297           297          297
# 2019-09-22  286          286    286   286           286          286
# 2019-09-29  246          246    246   246           246          246
# 2019-10-06  221          221    221   221           221          221
# 2019-10-13  246          246    246   246           246          246
# 2019-10-20  264          264    264   264           264          264
# 2019-10-27  262          262    262   262           262          262
# 2019-11-03  234          234    234   234           234          234
# 2019-11-10  245          245    245   245           245          245
# 2019-11-17  198          198    198   198           198          198
# 2019-11-24  274          274    274   274           274          274
# 2019-12-01  245          245    245   245           245          245
# 2019-12-08  280          280    280   280           280          280
# 2019-12-15  207          207    207   207           207          207
# 2019-12-22  264          264    264   264           264          264
# 2019-12-29  276          276    276   276           276          276
# 2020-01-05  319          319    319   319           319          319
# 2020-01-12  219          219    219   219           219          219
# 2020-01-19  227          227    227   227           227          227
# 2020-01-26  241          241    241   241           241          241
# 2020-02-02  264          264    264   264           264          264
# 2020-02-09  235          235    235   235           235          235
# 2020-02-16  214          214    214   214           214          214
# 2020-02-23  276          276    276   276           276          276
# 2020-03-01  208          208    208   208           208          208
# 2020-03-08  232          232    232   232           232          232
# 2020-03-15  230          230    230   230           230          230
# 2020-03-22  214          214    214   214           214          214
# 2020-03-29  224          224    224   224           224          224
# 2020-04-05  234          234    234   234           234          234
# 2020-04-12  270          270    270   270           270          270
# 2020-04-19  230          230    230   230           230          230
# 2020-04-26  235          235    235   235           235          235
# 2020-05-03  272          272    272   272           272          272
# 2020-05-10  254          254    254   254           254          254
# 2020-05-17  334          334    334   334           334          334
# 2020-05-24  363          363    363   363           363          363
# 2020-05-31  491          491    491   491           491          491
# 2020-06-07  544          544    544   544           544          544
# 2020-06-14  346          346    346   346           346          346
# 2020-06-21  377          377    377   377           377          377
# 2020-06-28  374          374    374   374           374          374
# 2020-07-05  418          418    418   418           418          418
# 2020-07-12  363          363    363   363           363          363
# 2020-07-19  402          402    402   402           402          402
# 2020-07-26  387          387    387   387           387          387
# 2020-08-02  378          378    378   378           378          378
# 2020-08-09  423          423    423   423           423          423
# 2020-08-16  447          447    447   447           447          447
# 2020-08-23  439          439    439   439           439          439
# 2020-08-30  458          458    458   458           458          458
# 2020-09-06  455          455    455   455           455          455
# 2020-09-13  396          396    396   396           396          396
# 2020-09-20  379          379    379   379           379          379
# 2020-09-27  421          421    421   421           421          421
# 2020-10-04  341          341    341   341           341          341
# 2020-10-11  412          412    412   412           412          412
# 2020-10-18  377          377    377   377           377          377
# 2020-10-25  368          368    368   368           368          368
# 2020-11-01  389          389    389   389           389          389
# 2020-11-08  428          428    428   428           428          428
# 2020-11-15  310          310    310   310           310          310
# 2020-11-22  347          347    347   347           347          347
# 2020-11-29  380          380    380   380           380          380
# 2020-12-06  340          340    340   340           340          340
# 2020-12-13  331          331    331   331           331          331
# 2020-12-20  349          349    349   349           349          349
# 2020-12-27  297          297    297   297           297          297
# 2021-01-03  355          355    355   355           355          355
# 2021-01-10  350          350    350   350           350          350
# 2021-01-17  300          300    300   300           300          300
# 2021-01-24  321          321    321   321           321          321
# 2021-01-31  250          250    250   250           250          250
# 2021-02-07  254          254    254   254           254          254
# 2021-02-14  131          131    131   131           131          131
#
#             Location Description  Arrest  Domestic  Beat  ...  FBI Code  \
# Date                                                      ...
# 2014-01-05                   156     156       156   156  ...       156
# 2014-01-12                   133     133       133   133  ...       133
# 2014-01-19                   172     172       172   172  ...       172
# 2014-01-26                   172     172       172   172  ...       172
# 2014-02-02                   156     156       156   156  ...       156
# 2014-02-09                   120     120       120   120  ...       120
# 2014-02-16                   113     113       113   113  ...       113
# 2014-02-23                   104     104       104   104  ...       104
# 2014-03-02                   117     117       117   117  ...       117
# 2014-03-09                   131     131       131   131  ...       131
# 2014-03-16                   146     146       146   146  ...       146
# 2014-03-23                   166     166       166   166  ...       166
# 2014-03-30                   132     132       132   132  ...       132
# 2014-04-06                   171     171       171   171  ...       171
# 2014-04-13                   221     221       221   221  ...       221
# 2014-04-20                   215     215       215   215  ...       215
# 2014-04-27                   215     215       215   215  ...       215
# 2014-05-04                   208     208       208   208  ...       208
# 2014-05-11                   218     218       218   218  ...       218
# 2014-05-18                   222     222       222   222  ...       222
# 2014-05-25                   218     218       218   218  ...       218
# 2014-06-01                   218     218       218   218  ...       218
# 2014-06-08                   206     206       206   206  ...       206
# 2014-06-15                   231     231       231   231  ...       231
# 2014-06-22                   234     234       234   234  ...       234
# 2014-06-29                   235     235       235   235  ...       235
# 2014-07-06                   249     249       249   249  ...       249
# 2014-07-13                   233     233       233   233  ...       233
# 2014-07-20                   220     220       220   220  ...       220
# 2014-07-27                   224     224       224   224  ...       224
# 2014-08-03                   227     227       227   227  ...       227
# 2014-08-10                   201     201       201   201  ...       201
# 2014-08-17                   221     221       221   221  ...       221
# 2014-08-24                   206     206       206   206  ...       206
# 2014-08-31                   205     205       205   205  ...       205
# 2014-09-07                   176     176       176   176  ...       176
# 2014-09-14                   170     170       170   170  ...       170
# 2014-09-21                   203     203       203   203  ...       203
# 2014-09-28                   256     256       256   256  ...       256
# 2014-10-05                   212     212       212   212  ...       212
# 2014-10-12                   164     164       164   164  ...       164
# 2014-10-19                   196     196       196   196  ...       196
# 2014-10-26                   230     230       230   230  ...       230
# 2014-11-02                   224     224       224   224  ...       224
# 2014-11-09                   174     174       174   174  ...       174
# 2014-11-16                   190     190       190   190  ...       190
# 2014-11-23                   179     179       179   179  ...       179
# 2014-11-30                   177     177       177   177  ...       177
# 2014-12-07                   201     201       201   201  ...       201
# 2014-12-14                   228     228       228   228  ...       228
# 2014-12-21                   238     238       238   238  ...       238
# 2014-12-28                   217     217       217   217  ...       217
# 2015-01-04                   192     192       192   192  ...       192
# 2015-01-11                   144     144       144   144  ...       144
# 2015-01-18                   175     175       175   175  ...       175
# 2015-01-25                   217     217       217   217  ...       217
# 2015-02-01                   154     154       154   154  ...       154
# 2015-02-08                   128     128       128   128  ...       128
# 2015-02-15                   118     118       118   118  ...       118
# 2015-02-22                   123     123       123   123  ...       123
# 2015-03-01                   143     143       143   143  ...       143
# 2015-03-08                   172     172       172   172  ...       172
# 2015-03-15                   206     206       206   206  ...       206
# 2015-03-22                   199     199       199   199  ...       199
# 2015-03-29                   181     181       181   181  ...       181
# 2015-04-05                   218     218       218   218  ...       218
# 2015-04-12                   209     209       209   209  ...       209
# 2015-04-19                   207     207       207   207  ...       207
# 2015-04-26                   202     202       202   202  ...       202
# 2015-05-03                   193     193       193   193  ...       193
# 2015-05-10                   179     179       179   179  ...       179
# 2015-05-17                   256     256       256   256  ...       256
# 2015-05-24                   242     242       242   242  ...       242
# 2015-05-31                   232     232       232   232  ...       232
# 2015-06-07                   202     202       202   202  ...       202
# 2015-06-14                   230     230       230   230  ...       230
# 2015-06-21                   238     238       238   238  ...       238
# 2015-06-28                   237     237       237   237  ...       237
# 2015-07-05                   253     253       253   253  ...       253
# 2015-07-12                   227     227       227   227  ...       227
# 2015-07-19                   238     238       238   238  ...       238
# 2015-07-26                   268     268       268   268  ...       268
# 2015-08-02                   283     284       284   284  ...       284
# 2015-08-09                   247     247       247   247  ...       247
# 2015-08-16                   238     238       238   238  ...       238
# 2015-08-23                   261     261       261   261  ...       261
# 2015-08-30                   250     250       250   250  ...       250
# 2015-09-06                   260     260       260   260  ...       260
# 2015-09-13                   226     226       226   226  ...       226
# 2015-09-20                   247     247       247   247  ...       247
# 2015-09-27                   275     275       275   275  ...       275
# 2015-10-04                   236     236       236   236  ...       236
# 2015-10-11                   218     218       218   218  ...       218
# 2015-10-18                   203     203       203   203  ...       203
# 2015-10-25                   266     266       266   266  ...       266
# 2015-11-01                   232     232       232   232  ...       232
# 2015-11-08                   195     195       195   195  ...       195
# 2015-11-15                   212     212       212   212  ...       212
# 2015-11-22                   185     185       185   185  ...       185
# 2015-11-29                   201     201       201   201  ...       201
# 2015-12-06                   207     207       207   207  ...       207
# 2015-12-13                   199     199       199   199  ...       199
# 2015-12-20                   216     216       216   216  ...       216
# 2015-12-27                   236     236       236   236  ...       236
# 2016-01-03                   224     224       224   224  ...       224
# 2016-01-10                   253     253       253   253  ...       253
# 2016-01-17                   215     215       215   215  ...       215
# 2016-01-24                   226     226       226   226  ...       226
# 2016-01-31                   250     250       250   250  ...       250
# 2016-02-07                   208     208       208   208  ...       208
# 2016-02-14                   162     162       162   162  ...       162
# 2016-02-21                   190     190       190   190  ...       190
# 2016-02-28                   194     194       194   194  ...       194
# 2016-03-06                   182     182       182   182  ...       182
# 2016-03-13                   255     255       255   255  ...       255
# 2016-03-20                   236     236       236   236  ...       236
# 2016-03-27                   239     239       239   239  ...       239
# 2016-04-03                   257     257       257   257  ...       257
# 2016-04-10                   212     212       212   212  ...       212
# 2016-04-17                   292     292       292   292  ...       292
# 2016-04-24                   273     273       273   273  ...       273
# 2016-05-01                   230     230       230   230  ...       230
# 2016-05-08                   293     293       293   293  ...       293
# 2016-05-15                   247     247       247   247  ...       247
# 2016-05-22                   316     316       316   316  ...       316
# 2016-05-29                   313     313       313   313  ...       313
# 2016-06-05                   308     308       308   308  ...       308
# 2016-06-12                   282     282       282   282  ...       282
# 2016-06-19                   304     304       304   304  ...       304
# 2016-06-26                   298     298       298   298  ...       298
# 2016-07-03                   297     297       297   297  ...       297
# 2016-07-10                   349     349       349   349  ...       349
# 2016-07-17                   290     290       290   290  ...       290
# 2016-07-24                   286     286       286   286  ...       286
# 2016-07-31                   316     316       316   316  ...       316
# 2016-08-07                   323     323       323   323  ...       323
# 2016-08-14                   326     326       326   326  ...       326
# 2016-08-21                   327     327       327   327  ...       327
# 2016-08-28                   352     352       352   352  ...       352
# 2016-09-04                   336     336       336   336  ...       336
# 2016-09-11                   294     294       294   294  ...       294
# 2016-09-18                   285     285       285   285  ...       285
# 2016-09-25                   299     299       299   299  ...       299
# 2016-10-02                   253     253       253   253  ...       253
# 2016-10-09                   279     279       279   279  ...       279
# 2016-10-16                   326     326       326   326  ...       326
# 2016-10-23                   311     311       311   311  ...       311
# 2016-10-30                   292     292       292   292  ...       292
# 2016-11-06                   363     363       363   363  ...       363
# 2016-11-13                   309     309       309   309  ...       309
# 2016-11-20                   278     278       278   278  ...       278
# 2016-11-27                   298     298       298   298  ...       298
# 2016-12-04                   281     281       281   281  ...       281
# 2016-12-11                   225     225       225   225  ...       225
# 2016-12-18                   218     218       218   218  ...       218
# 2016-12-25                   264     264       264   264  ...       264
# 2017-01-01                   349     349       349   349  ...       349
# 2017-01-08                   254     254       254   254  ...       254
# 2017-01-15                   277     277       277   277  ...       277
# 2017-01-22                   304     304       304   304  ...       304
# 2017-01-29                   264     264       264   264  ...       264
# 2017-02-05                   283     283       283   283  ...       283
# 2017-02-12                   258     258       258   258  ...       258
# 2017-02-19                   279     279       279   279  ...       279
# 2017-02-26                   211     211       211   211  ...       211
# 2017-03-05                   211     211       211   211  ...       211
# 2017-03-12                   209     209       209   209  ...       209
# 2017-03-19                   202     202       202   202  ...       202
# 2017-03-26                   258     258       258   258  ...       258
# 2017-04-02                   229     229       229   229  ...       229
# 2017-04-09                   229     229       229   229  ...       229
# 2017-04-16                   335     335       335   335  ...       335
# 2017-04-23                   305     305       305   305  ...       305
# 2017-04-30                   274     274       274   274  ...       274
# 2017-05-07                   246     246       246   246  ...       246
# 2017-05-14                   256     256       256   256  ...       256
# 2017-05-21                   296     296       296   296  ...       296
# 2017-05-28                   303     303       303   303  ...       303
# 2017-06-04                   317     317       317   317  ...       317
# 2017-06-11                   318     318       318   318  ...       318
# 2017-06-18                   265     265       265   265  ...       265
# 2017-06-25                   298     298       298   298  ...       298
# 2017-07-02                   322     322       322   322  ...       322
# 2017-07-09                   378     378       378   378  ...       378
# 2017-07-16                   302     302       302   302  ...       302
# 2017-07-23                   309     309       309   309  ...       309
# 2017-07-30                   301     301       301   301  ...       301
# 2017-08-06                   285     285       285   285  ...       285
# 2017-08-13                   289     289       289   289  ...       289
# 2017-08-20                   321     321       321   321  ...       321
# 2017-08-27                   316     316       316   316  ...       316
# 2017-09-03                   353     353       353   353  ...       353
# 2017-09-10                   296     296       296   296  ...       296
# 2017-09-17                   267     267       267   267  ...       267
# 2017-09-24                   306     306       306   306  ...       306
# 2017-10-01                   287     287       287   287  ...       287
# 2017-10-08                   282     282       282   282  ...       282
# 2017-10-15                   273     273       273   273  ...       273
# 2017-10-22                   296     296       296   296  ...       296
# 2017-10-29                   309     309       309   309  ...       309
# 2017-11-05                   299     299       299   299  ...       299
# 2017-11-12                   289     289       289   289  ...       289
# 2017-11-19                   263     263       263   263  ...       263
# 2017-11-26                   273     273       273   273  ...       273
# 2017-12-03                   291     291       291   291  ...       291
# 2017-12-10                   275     275       275   275  ...       275
# 2017-12-17                   266     266       266   266  ...       266
# 2017-12-24                   267     267       267   267  ...       267
# 2017-12-31                   222     222       222   222  ...       222
# 2018-01-07                   283     283       283   283  ...       283
# 2018-01-14                   266     266       266   266  ...       266
# 2018-01-21                   247     247       247   247  ...       247
# 2018-01-28                   276     276       276   276  ...       276
# 2018-02-04                   213     213       213   213  ...       213
# 2018-02-11                   166     166       166   166  ...       166
# 2018-02-18                   217     217       217   217  ...       217
# 2018-02-25                   242     242       242   242  ...       242
# 2018-03-04                   224     224       224   224  ...       224
# 2018-03-11                   238     238       238   238  ...       238
# 2018-03-18                   227     227       227   227  ...       227
# 2018-03-25                   235     235       235   235  ...       235
# 2018-04-01                   237     237       237   237  ...       237
# 2018-04-08                   193     193       193   193  ...       193
# 2018-04-15                   276     276       276   276  ...       276
# 2018-04-22                   245     245       245   245  ...       245
# 2018-04-29                   260     260       260   260  ...       260
# 2018-05-06                   307     307       307   307  ...       307
# 2018-05-13                   276     276       276   276  ...       276
# 2018-05-20                   295     295       295   295  ...       295
# 2018-05-27                   344     344       344   344  ...       344
# 2018-06-03                   312     312       312   312  ...       312
# 2018-06-10                   313     313       313   313  ...       313
# 2018-06-17                   305     305       305   305  ...       305
# 2018-06-24                   268     268       268   268  ...       268
# 2018-07-01                   354     354       354   354  ...       354
# 2018-07-08                   333     333       333   333  ...       333
# 2018-07-15                   302     302       302   302  ...       302
# 2018-07-22                   294     294       294   294  ...       294
# 2018-07-29                   323     323       323   323  ...       323
# 2018-08-05                   328     328       328   328  ...       328
# 2018-08-12                   325     325       325   325  ...       325
# 2018-08-19                   321     321       321   321  ...       321
# 2018-08-26                   268     268       268   268  ...       268
# 2018-09-02                   322     322       322   322  ...       322
# 2018-09-09                   268     268       268   268  ...       268
# 2018-09-16                   268     268       268   268  ...       268
# 2018-09-23                   287     287       287   287  ...       287
# 2018-09-30                   251     251       251   251  ...       251
# 2018-10-07                   253     253       253   253  ...       253
# 2018-10-14                   264     264       264   264  ...       264
# 2018-10-21                   235     235       235   235  ...       235
# 2018-10-28                   288     288       288   288  ...       288
# 2018-11-04                   275     275       275   275  ...       275
# 2018-11-11                   258     258       258   258  ...       258
# 2018-11-18                   232     232       232   232  ...       232
# 2018-11-25                   228     228       228   228  ...       228
# 2018-12-02                   241     241       241   241  ...       241
# 2018-12-09                   256     256       256   256  ...       256
# 2018-12-16                   250     250       250   250  ...       250
# 2018-12-23                   256     256       256   256  ...       256
# 2018-12-30                   289     289       289   289  ...       289
# 2019-01-06                   328     328       328   328  ...       328
# 2019-01-13                   222     222       222   222  ...       222
# 2019-01-20                   240     240       240   240  ...       240
# 2019-01-27                   208     208       208   208  ...       208
# 2019-02-03                   172     172       172   172  ...       172
# 2019-02-10                   195     195       195   195  ...       195
# 2019-02-17                   215     215       215   215  ...       215
# 2019-02-24                   216     216       216   216  ...       216
# 2019-03-03                   201     201       201   201  ...       201
# 2019-03-10                   195     195       195   195  ...       195
# 2019-03-17                   219     219       219   219  ...       219
# 2019-03-24                   236     236       236   236  ...       236
# 2019-03-31                   256     256       256   256  ...       256
# 2019-04-07                   249     249       249   249  ...       249
# 2019-04-14                   244     244       244   244  ...       244
# 2019-04-21                   275     275       275   275  ...       275
# 2019-04-28                   288     288       288   288  ...       288
# ...
# 2020-09-27           421           421   421         421       421        421
# 2020-10-04           340           340   341         341       340        340
# 2020-10-11           412           412   412         412       412        412
# 2020-10-18           377           377   377         377       377        377
# 2020-10-25           367           367   368         368       367        367
# 2020-11-01           389           389   389         389       389        389
# 2020-11-08           428           428   428         428       428        428
# 2020-11-15           309           309   310         310       309        309
# 2020-11-22           347           347   347         347       347        347
# 2020-11-29           380           380   380         380       380        380
# 2020-12-06           340           340   340         340       340        340
# 2020-12-13           331           331   331         331       331        331
# 2020-12-20           349           349   349         349       349        349
# 2020-12-27           297           297   297         297       297        297
# 2021-01-03           354           354   355         355       354        354
# 2021-01-10           350           350   350         350       350        350
# 2021-01-17           300           300   300         300       300        300
# 2021-01-24           321           321   321         321       321        321
# 2021-01-31           250           250   250         250       250        250
# 2021-02-07           249           249   254         254       249        249
# 2021-02-14            45            45   131         131        45         45
#
#             Location  month  winter
# Date
# 2014-01-05       156    156     156
# 2014-01-12       133    133     133
# 2014-01-19       172    172     172
# 2014-01-26       172    172     172
# 2014-02-02       156    156     156
# 2014-02-09       120    120     120
# 2014-02-16       113    113     113
# 2014-02-23       104    104     104
# 2014-03-02       117    117     117
# 2014-03-09       131    131     131
# 2014-03-16       146    146     146
# 2014-03-23       166    166     166
# 2014-03-30       132    132     132
# 2014-04-06       171    171     171
# 2014-04-13       221    221     221
# 2014-04-20       215    215     215
# 2014-04-27       215    215     215
# 2014-05-04       208    208     208
# 2014-05-11       218    218     218
# 2014-05-18       222    222     222
# 2014-05-25       218    218     218
# 2014-06-01       218    218     218
# 2014-06-08       206    206     206
# 2014-06-15       231    231     231
# 2014-06-22       234    234     234
# 2014-06-29       235    235     235
# 2014-07-06       248    249     249
# 2014-07-13       233    233     233
# 2014-07-20       220    220     220
# 2014-07-27       224    224     224
# 2014-08-03       225    227     227
# 2014-08-10       201    201     201
# 2014-08-17       221    221     221
# 2014-08-24       206    206     206
# 2014-08-31       205    205     205
# 2014-09-07       176    176     176
# 2014-09-14       170    170     170
# 2014-09-21       203    203     203
# 2014-09-28       256    256     256
# 2014-10-05       211    212     212
# 2014-10-12       163    164     164
# 2014-10-19       196    196     196
# 2014-10-26       229    230     230
# 2014-11-02       224    224     224
# 2014-11-09       174    174     174
# 2014-11-16       190    190     190
# 2014-11-23       179    179     179
# 2014-11-30       177    177     177
# 2014-12-07       200    201     201
# 2014-12-14       228    228     228
# 2014-12-21       237    238     238
# 2014-12-28       217    217     217
# 2015-01-04       192    192     192
# 2015-01-11       144    144     144
# 2015-01-18       175    175     175
# 2015-01-25       217    217     217
# 2015-02-01       153    154     154
# 2015-02-08       128    128     128
# 2015-02-15       118    118     118
# 2015-02-22       123    123     123
# 2015-03-01       142    143     143
# 2015-03-08       172    172     172
# 2015-03-15       206    206     206
# 2015-03-22       198    199     199
# 2015-03-29       181    181     181
# 2015-04-05       217    218     218
# 2015-04-12       208    209     209
# 2015-04-19       207    207     207
# 2015-04-26       202    202     202
# 2015-05-03       192    193     193
# 2015-05-10       179    179     179
# 2015-05-17       255    256     256
# 2015-05-24       241    242     242
# 2015-05-31       232    232     232
# 2015-06-07       201    202     202
# 2015-06-14       227    230     230
# 2015-06-21       238    238     238
# 2015-06-28       237    237     237
# 2015-07-05       250    253     253
# 2015-07-12       227    227     227
# 2015-07-19       238    238     238
# 2015-07-26       268    268     268
# 2015-08-02       284    284     284
# 2015-08-09       247    247     247
# 2015-08-16       238    238     238
# 2015-08-23       258    261     261
# 2015-08-30       247    250     250
# 2015-09-06       259    260     260
# 2015-09-13       225    226     226
# 2015-09-20       246    247     247
# 2015-09-27       271    275     275
# 2015-10-04       235    236     236
# 2015-10-11       217    218     218
# 2015-10-18       203    203     203
# 2015-10-25       266    266     266
# 2015-11-01       232    232     232
# 2015-11-08       195    195     195
# 2015-11-15       211    212     212
# 2015-11-22       185    185     185
# 2015-11-29       201    201     201
# 2015-12-06       206    207     207
# 2015-12-13       198    199     199
# 2015-12-20       216    216     216
# 2015-12-27       235    236     236
# 2016-01-03       223    224     224
# 2016-01-10       253    253     253
# 2016-01-17       215    215     215
# 2016-01-24       226    226     226
# 2016-01-31       250    250     250
# 2016-02-07       208    208     208
# 2016-02-14       162    162     162
# 2016-02-21       190    190     190
# 2016-02-28       194    194     194
# 2016-03-06       182    182     182
# 2016-03-13       255    255     255
# 2016-03-20       236    236     236
# 2016-03-27       239    239     239
# 2016-04-03       257    257     257
# 2016-04-10       212    212     212
# 2016-04-17       292    292     292
# 2016-04-24       273    273     273
# 2016-05-01       230    230     230
# 2016-05-08       293    293     293
# 2016-05-15       247    247     247
# 2016-05-22       316    316     316
# 2016-05-29       313    313     313
# 2016-06-05       308    308     308
# 2016-06-12       282    282     282
# 2016-06-19       304    304     304
# 2016-06-26       297    298     298
# 2016-07-03       297    297     297
# 2016-07-10       349    349     349
# 2016-07-17       290    290     290
# 2016-07-24       286    286     286
# 2016-07-31       316    316     316
# 2016-08-07       322    323     323
# 2016-08-14       325    326     326
# 2016-08-21       327    327     327
# 2016-08-28       351    352     352
# 2016-09-04       336    336     336
# 2016-09-11       294    294     294
# 2016-09-18       285    285     285
# 2016-09-25       299    299     299
# 2016-10-02       253    253     253
# 2016-10-09       279    279     279
# 2016-10-16       326    326     326
# 2016-10-23       311    311     311
# 2016-10-30       292    292     292
# 2016-11-06       363    363     363
# 2016-11-13       309    309     309
# 2016-11-20       278    278     278
# 2016-11-27       298    298     298
# 2016-12-04       281    281     281
# 2016-12-11       225    225     225
# 2016-12-18       217    218     218
# 2016-12-25       264    264     264
# 2017-01-01       349    349     349
# 2017-01-08       253    254     254
# 2017-01-15       276    277     277
# 2017-01-22       304    304     304
# 2017-01-29       264    264     264
# 2017-02-05       283    283     283
# 2017-02-12       258    258     258
# 2017-02-19       278    279     279
# 2017-02-26       211    211     211
# 2017-03-05       211    211     211
# 2017-03-12       209    209     209
# 2017-03-19       202    202     202
# 2017-03-26       258    258     258
# 2017-04-02       229    229     229
# 2017-04-09       229    229     229
# 2017-04-16       334    335     335
# 2017-04-23       305    305     305
# 2017-04-30       274    274     274
# 2017-05-07       246    246     246
# 2017-05-14       256    256     256
# 2017-05-21       296    296     296
# 2017-05-28       303    303     303
# 2017-06-04       316    317     317
# 2017-06-11       318    318     318
# 2017-06-18       265    265     265
# 2017-06-25       298    298     298
# 2017-07-02       322    322     322
# 2017-07-09       378    378     378
# 2017-07-16       302    302     302
# 2017-07-23       309    309     309
# 2017-07-30       301    301     301
# 2017-08-06       285    285     285
# 2017-08-13       289    289     289
# 2017-08-20       321    321     321
# 2017-08-27       316    316     316
# 2017-09-03       353    353     353
# 2017-09-10       296    296     296
# 2017-09-17       267    267     267
# 2017-09-24       306    306     306
# 2017-10-01       287    287     287
# 2017-10-08       282    282     282
# 2017-10-15       273    273     273
# 2017-10-22       294    296     296
# 2017-10-29       309    309     309
# 2017-11-05       299    299     299
# 2017-11-12       288    289     289
# 2017-11-19       262    263     263
# 2017-11-26       273    273     273
# 2017-12-03       291    291     291
# 2017-12-10       274    275     275
# 2017-12-17       265    266     266
# 2017-12-24       267    267     267
# 2017-12-31       222    222     222
# 2018-01-07       283    283     283
# 2018-01-14       266    266     266
# 2018-01-21       247    247     247
# 2018-01-28       276    276     276
# 2018-02-04       213    213     213
# 2018-02-11       165    166     166
# 2018-02-18       217    217     217
# 2018-02-25       242    242     242
# 2018-03-04       224    224     224
# 2018-03-11       238    238     238
# 2018-03-18       227    227     227
# 2018-03-25       235    235     235
# 2018-04-01       237    237     237
# 2018-04-08       193    193     193
# 2018-04-15       276    276     276
# 2018-04-22       245    245     245
# 2018-04-29       260    260     260
# 2018-05-06       306    307     307
# 2018-05-13       274    276     276
# 2018-05-20       294    295     295
# 2018-05-27       344    344     344
# 2018-06-03       310    312     312
# 2018-06-10       313    313     313
# 2018-06-17       304    305     305
# 2018-06-24       268    268     268
# 2018-07-01       354    354     354
# 2018-07-08       333    333     333
# 2018-07-15       301    302     302
# 2018-07-22       293    294     294
# 2018-07-29       322    323     323
# 2018-08-05       328    328     328
# 2018-08-12       325    325     325
# 2018-08-19       321    321     321
# 2018-08-26       268    268     268
# 2018-09-02       322    322     322
# 2018-09-09       267    268     268
# 2018-09-16       267    268     268
# 2018-09-23       287    287     287
# 2018-09-30       251    251     251
# 2018-10-07       252    253     253
# 2018-10-14       264    264     264
# 2018-10-21       235    235     235
# 2018-10-28       288    288     288
# 2018-11-04       273    275     275
# 2018-11-11       258    258     258
# 2018-11-18       230    232     232
# 2018-11-25       227    228     228
# 2018-12-02       240    241     241
# 2018-12-09       256    256     256
# 2018-12-16       249    250     250
# 2018-12-23       255    256     256
# 2018-12-30       288    289     289
# 2019-01-06       328    328     328
# 2019-01-13       222    222     222
# 2019-01-20       240    240     240
# 2019-01-27       207    208     208
# 2019-02-03       172    172     172
# 2019-02-10       195    195     195
# 2019-02-17       215    215     215
# 2019-02-24       216    216     216
# 2019-03-03       201    201     201
# 2019-03-10       195    195     195
# 2019-03-17       219    219     219
# 2019-03-24       236    236     236
# 2019-03-31       256    256     256
# 2019-04-07       249    249     249
# 2019-04-14       244    244     244
# 2019-04-21       275    275     275
# 2019-04-28       288    288     288
# 2019-05-05       254    254     254
# 2019-05-12       238    238     238
# 2019-05-19       262    262     262
# 2019-05-26       346    346     346
# 2019-06-02       288    288     288
# 2019-06-09       321    321     321
# 2019-06-16       270    270     270
# 2019-06-23       259    259     259
# 2019-06-30       347    347     347
# 2019-07-07       351    351     351
# 2019-07-14       280    280     280
# 2019-07-21       317    317     317
# 2019-07-28       312    312     312
# 2019-08-04       335    335     335
# 2019-08-11       354    354     354
# 2019-08-18       300    300     300
# 2019-08-25       280    280     280
# 2019-09-01       280    280     280
# 2019-09-08       251    251     251
# 2019-09-15       297    297     297
# 2019-09-22       286    286     286
# 2019-09-29       246    246     246
# 2019-10-06       221    221     221
# 2019-10-13       246    246     246
# 2019-10-20       264    264     264
# 2019-10-27       262    262     262
# 2019-11-03       234    234     234
# 2019-11-10       244    245     245
# 2019-11-17       198    198     198
# 2019-11-24       274    274     274
# 2019-12-01       245    245     245
# 2019-12-08       280    280     280
# 2019-12-15       207    207     207
# 2019-12-22       263    264     264
# 2019-12-29       276    276     276
# 2020-01-05       319    319     319
# 2020-01-12       219    219     219
# 2020-01-19       227    227     227
# 2020-01-26       241    241     241
# 2020-02-02       264    264     264
# 2020-02-09       235    235     235
# 2020-02-16       213    214     214
# 2020-02-23       276    276     276
# 2020-03-01       208    208     208
# 2020-03-08       232    232     232
# 2020-03-15       230    230     230
# 2020-03-22       214    214     214
# 2020-03-29       224    224     224
# 2020-04-05       233    234     234
# 2020-04-12       270    270     270
# 2020-04-19       230    230     230
# 2020-04-26       235    235     235
# 2020-05-03       272    272     272
# 2020-05-10       254    254     254
# 2020-05-17       334    334     334
# 2020-05-24       363    363     363
# 2020-05-31       491    491     491
# 2020-06-07       544    544     544
# 2020-06-14       346    346     346
# 2020-06-21       377    377     377
# 2020-06-28       374    374     374
# 2020-07-05       418    418     418
# 2020-07-12       363    363     363
# 2020-07-19       402    402     402
# 2020-07-26       387    387     387
# 2020-08-02       378    378     378
# 2020-08-09       422    423     423
# 2020-08-16       447    447     447
# 2020-08-23       439    439     439
# 2020-08-30       457    458     458
# 2020-09-06       454    455     455
# 2020-09-13       396    396     396
# 2020-09-20       379    379     379
# 2020-09-27       421    421     421
# 2020-10-04       340    341     341
# 2020-10-11       412    412     412
# 2020-10-18       377    377     377
# 2020-10-25       367    368     368
# 2020-11-01       389    389     389
# 2020-11-08       428    428     428
# 2020-11-15       309    310     310
# 2020-11-22       347    347     347
# 2020-11-29       380    380     380
# 2020-12-06       340    340     340
# 2020-12-13       331    331     331
# 2020-12-20       349    349     349
# 2020-12-27       297    297     297
# 2021-01-03       354    355     355
# 2021-01-10       350    350     350
# 2021-01-17       300    300     300
# 2021-01-24       321    321     321
# 2021-01-31       250    250     250
# 2021-02-07       249    254     254
# 2021-02-14        45    131     131
#
# [372 rows x 23 columns]

# %% [markdown]
# Our time series will consist of a series of counts of sales per day.

# %%
# Choosing Article_ID is unimportant.
# We could choose any column, as long as
# there are no nulls!
ts_resampled = ts.resample('D').count()['ID']

# %% [markdown]
# Let's visualize our timeseries with a plot.

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(ts_resampled.index, ts_resampled.values)
ax.set_title('Sales per Week')
ax.set_ylabel('Sales');

# %% [markdown]
# ## Aside: Deeper Exploration

# %%
print(ts_resampled.head(), ts_resampled.tail())
# Out:
# Date
# 2014-01-01    50
# 2014-01-02    33
# 2014-01-03    24
# 2014-01-04    32
# 2014-01-05    17
# Freq: D, Name: ID, dtype: int64 Date
# 2021-02-07    34
# 2021-02-08    30
# 2021-02-09    38
# 2021-02-10    34
# 2021-02-11    29
# Freq: D, Name: ID, dtype: int64

# %% [markdown]
# There are very large jumps in values at the beginning and at the end of our time series. In fact, we may suspect that the sales figures are incomplete.

# %% [markdown]
# Let's suppose that we want to amend the sales numbers at the two ends of our time series.
#
# There are several ways to do this. One way is to remove the outliers and populate an empty array with the original date range. That will introduce us to the `pandas.date_range()` method.
#
# Let's try this at the beginning of our series.

# %%
# Get rid of outlier at the beginning

# %%
# Resample within a given date range

# %%
# Create an empty array

# %%
# Turn array into Series

# %%
# Re-index series to weekly date-time object

# %%
# Fill nulls with data form weekly_count. Matches index on ojbects

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ts_new.plot(ax=ax)
ax.set_title('Sales with Small Outlier Removed');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5c31bc0cba94> in <module>
#       1 fig, ax = plt.subplots(figsize=(10, 5))
# ----> 2 ts_new.plot(ax=ax)
#       3 ax.set_title('Sales with Small Outlier Removed');
#
# NameError: name 'ts_new' is not defined

# %% [markdown]
# Let's zoom in on the first month:

# %%
fig, ax = plt.subplots()
ts_new[ts_new.index < '2017-01-24'].plot(ax=ax)
ax.tick_params(rotation=45)
ax.set_title('We have a gap at the start now');

# %% [markdown]
# In general, the datetime object allows us several options of how to fill those gaps:

# %% [markdown]
# ### `.bfill()`, `.ffill()`, and `.interpolate()`

# %% [markdown]
# The `.bfill()` time-series method will take known values and project them *backward* to fill gaps. Let's try that here:

# %%
print(ts_new.head(), '\n', '*'*30, '\n', ts_new.bfill().head())

# %%
# .bfill()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))

ts_new[ts_new.index < '2017-01-24'].plot(ax=ax1)
ax1.tick_params(rotation=45)
ax1.set_title('Original');


ts_new.bfill()[ts_new.index < '2017-01-24'].plot(ax=ax2)
ax2.tick_params(rotation=45)
ax2.set_title('Back Fill')

# %%
# Backfill

# %% [markdown]
# What about the end of our series? The value of 26 at the end is unusually low.

# %%
ts_new[(ts_new < 30) & (ts_new.index > '2018-01-01')]

# %% [markdown]
# The `.ffill()` time-series method will take known values and project them *forward* to fill gaps. Let's try that here. First we need to create the gap.

# %%
weekly_count = ts_new[~(ts_new < 30) | ~(ts_new.index > '2018-01-01')]

# %%
ts_wr = pd.date_range(ts_new.index[0], ts_new.index[-1], freq='W')
ts_weekly = np.empty(shape=len(ts_wr))
ts_weekly = pd.Series(ts_weekly)
ts_weekly = ts_weekly.reindex(ts_wr)
ts_new = ts_weekly.fillna(weekly_count)

# %%
print(ts_new.tail(), '\n', '*'*30, '\n', ts_new.ffill().tail())

# %%
# .ffill()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))

ax1.plot(ts_new[ts_new.index > '2019-01-01'])
ax1.tick_params(rotation=45)
ax1.set_title('Original');

ax2.plot(ts_new.ffill()[ts_new.index > '2019-01-01'])
ax2.tick_params(rotation=45)
ax2.set_title('Forward Fill')

# %%
# Forward fill

# %% [markdown]
# The `.interpolate()` time-series method will simply connect the endpoints that define a gap with a straight line.
#
# Suppose we wanted to smooth over the fluctuations in late 2017, which look like this:

# %%
ts_new[(ts_new.index > '2017-11-01') & (ts_new.index < '2018-01-15')]

# %% [markdown]
# We could treat the values for 11-26 through 12-24 as outliers and then fill in the gaps with the `.interpolate()` method. Let's try it!

# %% [markdown]
# ### Exercise
#
# Create a gap for the values between the dates **11-26-2017** and **12-24-2017** and then use the `.interpolate()` method to fill it in. Make a plot like the ones above to show the results of your work. The first couple lines are filled in for you.

# %%
# Your code here

# %% [markdown]
# Let's proceed with the data that has all of these filled-in values.

# %%
# Interpolate and plot

# %% [markdown]
# # Visualizing Time Series

# %% [markdown]
# There can be a lot information to be found in time series! Visualizations can help us tease out this information to something we can more easily observe.

# %% [markdown]
# ## Showing Changes Over Time

# %% [markdown]
# Can identify patterns and trends with visualizations

# %%
# New York Stock Exchange average monthly returns [1961-1966] from curriculum
nyse = pd.read_csv("data/NYSE_monthly.csv")
col_name= 'Month'
nyse[col_name] = pd.to_datetime(nyse[col_name])
nyse.set_index(col_name, inplace=True)

# %%
display(nyse.head(10))
display(nyse.info())

# %% [markdown]
# ### Line Plot

# %% [markdown]
# ### Dot Plot

# %% [markdown]
# > Note the difference between this and the line plot.
# >
# > When might you want a dot vs a line plot?

# %% [markdown]
# ### Grouping Plots

# %% [markdown]
# What if we wanted to look at year-to-year (e.g., temperature throughout many years)
#
# There are a couple options to choose from.

# %% [markdown]
# #### All Annual Separated

# %%
# Annual Frequency

# %%
# Create a new Empty DataFrame

# %%
# Store yearly values in columns

# %%
# Plot the yearly groups as subplots

# %% [markdown]
# #### All Annual Together

# %%
# Plot overlapping yearly groups

# %% [markdown]
# ## Showing Distributions

# %% [markdown]
# Sometimes the distribution of the values is important.
#
# What are some reasons?
#
# - Checking for normality (for stat testing)
# - First check on raw & transformed data

# %% [markdown]
# ### Histogram

# %%
# Histogram

# %%
# Bin it with correct bin number to make it more obvious if normal

# %% [markdown]
# ### Density

# %%
# KDE

# %% [markdown]
# ### Box Plot

# %% [markdown]
# - Shows distribution over time
# - Can help show outliers
# - Seasonal trends

# %%
# Generate a box and whiskers plot for nyse_annual dataframe

# %% [markdown]
# ### Heat Maps

# %% [markdown]
# Use color to show patterns throughout a time period for data

# %% [markdown]
# #### Example of how heat maps are useful

# %%
df_temp = pd.read_csv(
    'data/min_temp.csv',        # Data to read
    index_col=0,                # Use the first column as index ('Date')
    parse_dates=True,           # Have Pandas parse the dates
    infer_datetime_format=True, # Make Pandas try to parse dates automatically
    dayfirst=True               # Impoprtant to know format is DD/MM
)

# %%
display(df_temp.head())
display(df_temp.info())

# %%
# Create a new DataFrame and store yearly values in columns for temperature
temp_annual = pd.DataFrame()

for yr, group in df_temp.groupby(pd.Grouper(freq='A')):
    temp_annual[yr.year] = group.values.ravel()

# %%
temp_annual.head()

# %% [markdown]
# ##### Plotting each line plot in a subplot

# %% [markdown]
# Let's use our strategy in plotting multiple line plots to see if we can see a pattern:

# %%
# Plot the yearly groups as subplots
temp_annual.plot(figsize=(16, 8), subplots=True, legend=True)
plt.show()

# %% [markdown]
# You likely will have a hard time seeing exactly what the temperature shift is throughout the year (if it even exists!)
#
# We can try plotting all the lines together to see if a pattern is more obvious in our visual.

# %% [markdown]
# ##### Plotting all line plots in one plot

# %%
# Plot overlapping yearly groups 
temp_annual.plot(figsize=(15, 5), subplots=False, legend=True)
plt.show()

# %% [markdown]
# That's great we can see that the temperature decreases in the middle of the data! But now we sacrificed being able to observe any pattern for an individual year.
#
# This is where using a heat map can help visualize patterns throughout the year for temperature! And of course, the heat map can be used for more than just temperature related data.

# %% [markdown]
# ##### And finally, using a heat map to visualize a pattern

# %%
# Year and month 
year_matrix = temp_annual.T

# %%
plt.matshow(year_matrix, interpolation=None, aspect='auto', cmap=plt.cm.Spectral_r)
plt.show()

# %% [markdown]
# # Level Up: More EDA

# %%
raw = pd.read_csv('data/Historical_Data.csv')

# %%
raw.head()

# %% [markdown]
# Let's look at some summary stats:

# %%
print(f"There are {raw.shape[0]} records in our timeseries")

# %%
raw['Country_Code'].value_counts()

# %%
fig, ax = plt.subplots()

ccc = raw['Country_Code'].value_counts()
ax.bar(x=ccc.index, height=ccc);

# %%
raw['Article_ID'].value_counts()

# %%
fig, ax = plt.subplots()

aic = raw['Article_ID'].value_counts()
ax.bar(x=aic.index.astype(str), height=aic)
ax.tick_params(rotation=45, axis='x');

# %%
raw['Sold_Units'].value_counts()

# %%
fig, ax = plt.subplots(2, figsize=(6, 8))

suc = raw['Sold_Units'].value_counts()
ax[0].bar(x=suc.index[:6].astype(str), height=suc[:6])
ax[0].tick_params(rotation=45, axis='x')
ax[1].bar(x=suc.index[6:].astype(str), height=suc[6:])
ax[1].tick_params(rotation=45, axis='x');

# %%
raw['Country_Code'].value_counts().index

# %%
raw.loc[raw['Sold_Units'] == 101]

# %%
raw_rm = raw.drop(4298)

# %%
fig, ax = plt.subplots()

[raw_rm[raw_rm['Country_Code'] == code]['Sold_Units'].hist(figsize=(8, 6), ax=ax, label=code)\
     for code in raw_rm['Country_Code'].value_counts().index]
ax.set_title('Sold Unit Distributions by Country')
plt.legend();

# %%
fig, ax = plt.subplots()

[raw[raw['Country_Code'] == code]['Article_ID'].hist(figsize=(8, 6), ax=ax, label=code)\
     for code in raw['Country_Code'].value_counts().index]
ax.set_title('Article ID Distributions by Country')
plt.legend();

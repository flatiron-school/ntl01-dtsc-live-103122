# %% [markdown]
# # Natural Language Processing Checkpoint
# This checkpoint is designed to test your understanding of the content from the Text Classification Cumulative Lab.
#
# Specifically, this will cover:
#
# - Preprocessing and exploring text data using `nltk`
# - Vectorizing text data using a bag-of-words approach
# - Fitting machine learning models using vectorized text data
#
# ### Data Understanding
#
# In this repository under the file path `data/movie_descriptions.csv` there is a CSV file containing the titles, genres, and descriptions for 5,000 films pulled from [IMDb](https://www.kaggle.com/hijest/genre-classification-dataset-imdb).
#
# **The features of interest for this analysis will be:**
#
# 1. `desc`: The description of the film, which we will explore and then use as the features of our model
# 2. `genre`: The target for our predictive model

# %%
# Run this cell without changes
import pandas as pd

# Import the data
data = pd.read_csv('movie_descriptions.csv')

# Output a sample
data = data.sample(1500, random_state=100)
data.head()
# Out:
#          id                                           title          genre  \
# 789   31370                         Do You Believe? (2007)    documentary
# 2507  25529               The House That Jack Broke (2013)          drama
# 2376   5405                       Children of Peace (2016)    documentary
# 1378  49949                             Hwioribaram (2009)          drama
# 598   21445   Gui pian wang zhi zai xian xiong bang (1999)         horror
#
#                                                    desc
# 789    Do you believe?" digs deep into our spiritual...
# 2507   Early one morning, two FBI agents, Portman an...
# 2376   The Bosnian War was an international armed co...
# 1378   During winter vacation of their sophomore yea...
# 598    At a Hong Kong dormitory, the cook's little g...

# %%
# Run this cell without changes
data.genre.value_counts()
# Out:
#  documentary     495
#  drama           489
#  comedy          284
#  horror           82
#  thriller         56
#  action           49
#  western          45
# Name: genre, dtype: int64

# %% [markdown]
# ### Requirements
#
# 1. Initialize tokenizer and stemmer objects to prepare for text preprocessing
# 2. Write a function that implements standard "bag of words" text preprocessing
# 3. Initialize and fit a `CountVectorizer` from `sklearn`
# 3. Vectorize data using `CountVectorizer`
# 4. Fit a decision tree classifier on vectorized text data

# %% [markdown]
# ## 1) Initialize Tokenizer, Stemmer, and Stopwords Objects
#
# In our exploratory text analysis, we will:
#
# * Standardize case
# * Tokenize (split text into words)
# * Remove stopwords
# * Stem words
#
# Three of those steps require that we import some functionality from `nltk`. In the cell below, create:
#
# * An instance of `RegexpTokenizer` ([documentation here](https://www.nltk.org/api/nltk.tokenize.regexp.html#module-nltk.tokenize.regexp)) called `tokenizer`
#   * The regex pattern should select all words with three or more characters. You can use the pattern `r"(?u)\w{3,}"`
# * A list of stopwords (documentation [here](https://www.nltk.org/api/nltk.corpus.html#module-nltk.corpus) and [here](https://www.nltk.org/nltk_data/)) called `stopwords_list`
# * An instance of `PorterStemmer` ([documentation here](https://www.nltk.org/api/nltk.stem.porter.html)) called `stemmer`

# %%
# CodeGrade step1
# Run this line in a new cell if nltk isn't working
# !pip install nltk

# Replace None with appropriate code

import nltk
nltk.download('stopwords')
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# Create an intance of the RegexpTokenizer with the variable name `tokenizer`
# The regex pattern should select all words with three or more characters
pattern = r"(?u)\w{3,}"
tokenizer = RegexpTokenizer(pattern=pattern)

# Create a list of stopwords in English
stopwords_list = stopwords.words('english')

# Create an instance of nltk's PorterStemmer with the variable name `stemmer`
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jonathanfetterolf/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Checking that variables are no longer None
assert tokenizer
assert stopwords_list
assert stemmer

# %% [markdown]
# ## 2) Write a Function That Implements Standard Text Preprocessing
#
# In the cell below, complete the `preprocess_text` function so the inputted text is returned lower cased, tokenized, stopwords removed, and stemmed.
#
# For example, if you input the text
#
# ```
# This is an example sentence for preprocessing.
# ```
#
# The result of `preprocess_text` should be this list of strings:
#
# ```python
# ['exampl', 'sentenc', 'preprocess']
# ```

# %%
stopwords_list
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# CodeGrade step2
def preprocess_text(text, tokenizer, stopwords_list, stemmer):
    print(text)
    # Standardize case (lowercase the text)
    l_text = text.lower()
    print(l_text)
    # Tokenize text using `tokenizer`
    tokens = tokenizer.tokenize(l_text)
    print(tokens)
    # Remove stopwords using `stopwords_list`
    sw_text = [word for word in tokens if word not in stopwords_list]
    print(sw_text)
    # Stem the tokenized text using `stemmer`
    stemmed = [stemmer.stem(word) for word in sw_text]
    # Return the preprocessed text
    return stemmed
preprocess_text("This is an example sentence for preprocessing.", tokenizer, stopwords_list, stemmer)
# Out:
# This is an example sentence for preprocessing.
# this is an example sentence for preprocessing.
# ['this', 'example', 'sentence', 'for', 'preprocessing']
# ['example', 'sentence', 'preprocessing']
# ['exampl', 'sentenc', 'preprocess']

# %%
from types import FunctionType

assert type(preprocess_text) == FunctionType
assert type(preprocess_text('Example text', tokenizer, stopwords_list, stemmer)) == list
# Out:
# Example text
# example text
# ['example', 'text']
# ['example', 'text']

# %% [markdown]
# Now that the function has been created, use it to preprocess the entire dataset:

# %%
# Run this cell without changes
# (This may take a while due to nested loops)
text_data = data.desc.apply(lambda x: preprocess_text(x, tokenizer, stopwords_list, stemmer))
text_data
# Out:
#  Do you believe?" digs deep into our spiritual lives searching for answers to intangible questions. It has been developed over two years to investigate what makes us believe or disbelieve in God. As the research grew so did the points of the documentary and through those many new angles were presented and had to be approached and answered
#  do you believe?" digs deep into our spiritual lives searching for answers to intangible questions. it has been developed over two years to investigate what makes us believe or disbelieve in god. as the research grew so did the points of the documentary and through those many new angles were presented and had to be approached and answered
# ['you', 'believe', 'digs', 'deep', 'into', 'our', 'spiritual', 'lives', 'searching', 'for', 'answers', 'intangible', 'questions', 'has', 'been', 'developed', 'over', 'two', 'years', 'investigate', 'what', 'makes', 'believe', 'disbelieve', 'god', 'the', 'research', 'grew', 'did', 'the', 'points', 'the', 'documentary', 'and', 'through', 'those', 'many', 'new', 'angles', 'were', 'presented', 'and', 'had', 'approached', 'and', 'answered']
# ['believe', 'digs', 'deep', 'spiritual', 'lives', 'searching', 'answers', 'intangible', 'questions', 'developed', 'two', 'years', 'investigate', 'makes', 'believe', 'disbelieve', 'god', 'research', 'grew', 'points', 'documentary', 'many', 'new', 'angles', 'presented', 'approached', 'answered']
#  Early one morning, two FBI agents, Portman and Cross, visit the Peterson home. Jack Peterson, a young psychology professor, had just inherited the house from his grandfather. Portman and Cross question Jack concerning the murder of two young women and a handgun he once owned. Jack denies knowing or ever meeting the women and tells the FBI that the gun was lost long ago. The FBI continue to investigate Peterson's past and he continues to deny any involvement. Jack's wife, Anne, discovers the "lost" handgun in a box from the basement. This discovery builds tension and distrust between the couple. Jack assures her he will bring the gun to the FBI. Jack's escalating strange behavior raises not only the concerns of his wife, but also the FBI, who are watching him constantly. More things about his past start to unravel we find out that the suicide of his twin brother, Jimmy, brought on by post-traumatic-stress-disorder, led to Jack's creation of a drug formula. Does this formula have anything to do with the dead women? Is he being framed by a pharmaceutical giant or is Jack really a murderer? What develops is a story driven not just by the characters discovering clues to Jack's past, but also the relationships of those around Jack Peterson and the tight knit community of Greenville, Maine.
#  early one morning, two fbi agents, portman and cross, visit the peterson home. jack peterson, a young psychology professor, had just inherited the house from his grandfather. portman and cross question jack concerning the murder of two young women and a handgun he once owned. jack denies knowing or ever meeting the women and tells the fbi that the gun was lost long ago. the fbi continue to investigate peterson's past and he continues to deny any involvement. jack's wife, anne, discovers the "lost" handgun in a box from the basement. this discovery builds tension and distrust between the couple. jack assures her he will bring the gun to the fbi. jack's escalating strange behavior raises not only the concerns of his wife, but also the fbi, who are watching him constantly. more things about his past start to unravel we find out that the suicide of his twin brother, jimmy, brought on by post-traumatic-stress-disorder, led to jack's creation of a drug formula. does this formula have anything to do with the dead women? is he being framed by a pharmaceutical giant or is jack really a murderer? what develops is a story driven not just by the characters discovering clues to jack's past, but also the relationships of those around jack peterson and the tight knit community of greenville, maine.
# ['early', 'one', 'morning', 'two', 'fbi', 'agents', 'portman', 'and', 'cross', 'visit', 'the', 'peterson', 'home', 'jack', 'peterson', 'young', 'psychology', 'professor', 'had', 'just', 'inherited', 'the', 'house', 'from', 'his', 'grandfather', 'portman', 'and', 'cross', 'question', 'jack', 'concerning', 'the', 'murder', 'two', 'young', 'women', 'and', 'handgun', 'once', 'owned', 'jack', 'denies', 'knowing', 'ever', 'meeting', 'the', 'women', 'and', 'tells', 'the', 'fbi', 'that', 'the', 'gun', 'was', 'lost', 'long', 'ago', 'the', 'fbi', 'continue', 'investigate', 'peterson', 'past', 'and', 'continues', 'deny', 'any', 'involvement', 'jack', 'wife', 'anne', 'discovers', 'the', 'lost', 'handgun', 'box', 'from', 'the', 'basement', 'this', 'discovery', 'builds', 'tension', 'and', 'distrust', 'between', 'the', 'couple', 'jack', 'assures', 'her', 'will', 'bring', 'the', 'gun', 'the', 'fbi', 'jack', 'escalating', 'strange', 'behavior', 'raises', 'not', 'only', 'the', 'concerns', 'his', 'wife', 'but', 'also', 'the', 'fbi', 'who', 'are', 'watching', 'him', 'constantly', 'more', 'things', 'about', 'his', 'past', 'start', 'unravel', 'find', 'out', 'that', 'the', 'suicide', 'his', 'twin', 'brother', 'jimmy', 'brought', 'post', 'traumatic', 'stress', 'disorder', 'led', 'jack', 'creation', 'drug', 'formula', 'does', 'this', 'formula', 'have', 'anything', 'with', 'the', 'dead', 'women', 'being', 'framed', 'pharmaceutical', 'giant', 'jack', 'really', 'murderer', 'what', 'develops', 'story', 'driven', 'not', 'just', 'the', 'characters', 'discovering', 'clues', 'jack', 'past', 'but', 'also', 'the', 'relationships', 'those', 'around', 'jack', 'peterson', 'and', 'the', 'tight', 'knit', 'community', 'greenville', 'maine']
# ['early', 'one', 'morning', 'two', 'fbi', 'agents', 'portman', 'cross', 'visit', 'peterson', 'home', 'jack', 'peterson', 'young', 'psychology', 'professor', 'inherited', 'house', 'grandfather', 'portman', 'cross', 'question', 'jack', 'concerning', 'murder', 'two', 'young', 'women', 'handgun', 'owned', 'jack', 'denies', 'knowing', 'ever', 'meeting', 'women', 'tells', 'fbi', 'gun', 'lost', 'long', 'ago', 'fbi', 'continue', 'investigate', 'peterson', 'past', 'continues', 'deny', 'involvement', 'jack', 'wife', 'anne', 'discovers', 'lost', 'handgun', 'box', 'basement', 'discovery', 'builds', 'tension', 'distrust', 'couple', 'jack', 'assures', 'bring', 'gun', 'fbi', 'jack', 'escalating', 'strange', 'behavior', 'raises', 'concerns', 'wife', 'also', 'fbi', 'watching', 'constantly', 'things', 'past', 'start', 'unravel', 'find', 'suicide', 'twin', 'brother', 'jimmy', 'brought', 'post', 'traumatic', 'stress', 'disorder', 'led', 'jack', 'creation', 'drug', 'formula', 'formula', 'anything', 'dead', 'women', 'framed', 'pharmaceutical', 'giant', 'jack', 'really', 'murderer', 'develops', 'story', 'driven', 'characters', 'discovering', 'clues', 'jack', 'past', 'also', 'relationships', 'around', 'jack', 'peterson', 'tight', 'knit', 'community', 'greenville', 'maine']
#  The Bosnian War was an international armed conflict that took place in Bosnia and Herzegovina between 1992 and 1995. The most recent estimates suggest that around 100,000 people were killed during the war, 12,000 of them children. In addition, an estimated 20,000 to 50,000 women were raped, and over 2.2 million people were displaced, making it the most devastating conflict in Europe since the end of World War II. The war was brought to an end after the signing of the General Framework Agreement for Peace in Bosnia and Herzegovina in Paris on 14 December 1995. Now the country is more divided than at any time since the war ended. The new generations, born in peace, are growing divided. This is the story about them. About the day when 6 young people from 6 divided cities met and decided to do a performance about their mutual thoughts and beliefs.
#  the bosnian war was an international armed conflict that took place in bosnia and herzegovina between 1992 and 1995. the most recent estimates suggest that around 100,000 people were killed during the war, 12,000 of them children. in addition, an estimated 20,000 to 50,000 women were raped, and over 2.2 million people were displaced, making it the most devastating conflict in europe since the end of world war ii. the war was brought to an end after the signing of the general framework agreement for peace in bosnia and herzegovina in paris on 14 december 1995. now the country is more divided than at any time since the war ended. the new generations, born in peace, are growing divided. this is the story about them. about the day when 6 young people from 6 divided cities met and decided to do a performance about their mutual thoughts and beliefs.
# ['the', 'bosnian', 'war', 'was', 'international', 'armed', 'conflict', 'that', 'took', 'place', 'bosnia', 'and', 'herzegovina', 'between', '1992', 'and', '1995', 'the', 'most', 'recent', 'estimates', 'suggest', 'that', 'around', '100', '000', 'people', 'were', 'killed', 'during', 'the', 'war', '000', 'them', 'children', 'addition', 'estimated', '000', '000', 'women', 'were', 'raped', 'and', 'over', 'million', 'people', 'were', 'displaced', 'making', 'the', 'most', 'devastating', 'conflict', 'europe', 'since', 'the', 'end', 'world', 'war', 'the', 'war', 'was', 'brought', 'end', 'after', 'the', 'signing', 'the', 'general', 'framework', 'agreement', 'for', 'peace', 'bosnia', 'and', 'herzegovina', 'paris', 'december', '1995', 'now', 'the', 'country', 'more', 'divided', 'than', 'any', 'time', 'since', 'the', 'war', 'ended', 'the', 'new', 'generations', 'born', 'peace', 'are', 'growing', 'divided', 'this', 'the', 'story', 'about', 'them', 'about', 'the', 'day', 'when', 'young', 'people', 'from', 'divided', 'cities', 'met', 'and', 'decided', 'performance', 'about', 'their', 'mutual', 'thoughts', 'and', 'beliefs']
# ['bosnian', 'war', 'international', 'armed', 'conflict', 'took', 'place', 'bosnia', 'herzegovina', '1992', '1995', 'recent', 'estimates', 'suggest', 'around', '100', '000', 'people', 'killed', 'war', '000', 'children', 'addition', 'estimated', '000', '000', 'women', 'raped', 'million', 'people', 'displaced', 'making', 'devastating', 'conflict', 'europe', 'since', 'end', 'world', 'war', 'war', 'brought', 'end', 'signing', 'general', 'framework', 'agreement', 'peace', 'bosnia', 'herzegovina', 'paris', 'december', '1995', 'country', 'divided', 'time', 'since', 'war', 'ended', 'new', 'generations', 'born', 'peace', 'growing', 'divided', 'story', 'day', 'young', 'people', 'divided', 'cities', 'met', 'decided', 'performance', 'mutual', 'thoughts', 'beliefs']
#  During winter vacation of their sophomore year in high school, Tae-Hoon travels to the East Coast with Mi-Jeong to celebrate their 100th day anniversary. They spend happy times together and then go back home. When Tae-Hoon arrives back at home, he is scolded by his parents. Mi-Jung's parents call Tae-Hoon's parents to their home. Mi Jung's parents wants them to stop seeing each other.
#  during winter vacation of their sophomore year in high school, tae-hoon travels to the east coast with mi-jeong to celebrate their 100th day anniversary. they spend happy times together and then go back home. when tae-hoon arrives back at home, he is scolded by his parents. mi-jung's parents call tae-hoon's parents to their home. mi jung's parents wants them to stop seeing each other.
# ['during', 'winter', 'vacation', 'their', 'sophomore', 'year', 'high', 'school', 'tae', 'hoon', 'travels', 'the', 'east', 'coast', 'with', 'jeong', 'celebrate', 'their', '100th', 'day', 'anniversary', 'they', 'spend', 'happy', 'times', 'together', 'and', 'then', 'back', 'home', 'when', 'tae', 'hoon', 'arrives', 'back', 'home', 'scolded', 'his', 'parents', 'jung', 'parents', 'call', 'tae', 'hoon', 'parents', 'their', 'home', 'jung', 'parents', 'wants', 'them', 'stop', 'seeing', 'each', 'other']
# ['winter', 'vacation', 'sophomore', 'year', 'high', 'school', 'tae', 'hoon', 'travels', 'east', 'coast', 'jeong', 'celebrate', '100th', 'day', 'anniversary', 'spend', 'happy', 'times', 'together', 'back', 'home', 'tae', 'hoon', 'arrives', 'back', 'home', 'scolded', 'parents', 'jung', 'parents', 'call', 'tae', 'hoon', 'parents', 'home', 'jung', 'parents', 'wants', 'stop', 'seeing']
#  At a Hong Kong dormitory, the cook's little granddaughter is brutally murdered. The next day, a mysterious new student, Connie, moves into the dorm. As it is summer vacation, only four students are still living there. Mysterious, disastrous things seem to accompany the new girl everywhere she goes, and this school is no exception.
#  at a hong kong dormitory, the cook's little granddaughter is brutally murdered. the next day, a mysterious new student, connie, moves into the dorm. as it is summer vacation, only four students are still living there. mysterious, disastrous things seem to accompany the new girl everywhere she goes, and this school is no exception.
# ['hong', 'kong', 'dormitory', 'the', 'cook', 'little', 'granddaughter', 'brutally', 'murdered', 'the', 'next', 'day', 'mysterious', 'new', 'student', 'connie', 'moves', 'into', 'the', 'dorm', 'summer', 'vacation', 'only', 'four', 'students', 'are', 'still', 'living', 'there', 'mysterious', 'disastrous', 'things', 'seem', 'accompany', 'the', 'new', 'girl', 'everywhere', 'she', 'goes', 'and', 'this', 'school', 'exception']
# ['hong', 'kong', 'dormitory', 'cook', 'little', 'granddaughter', 'brutally', 'murdered', 'next', 'day', 'mysterious', 'new', 'student', 'connie', 'moves', 'dorm', 'summer', 'vacation', 'four', 'students', 'still', 'living', 'mysterious', 'disastrous', 'things', 'seem', 'accompany', 'new', 'girl', 'everywhere', 'goes', 'school', 'exception']
#  Gibson Bonifacio stopped speaking as a child. He is now twenty years old, returning to Manila from his studies abroad, his first visit home in three years. He finds his family trying to keep it together, his mother still hurting from a tragic loss in the past. In the backdrop of the vibrant local music scene, his childhood best friend reaches out to him, and he finds a chance at his first real romantic relationship. Amidst the holidays, Gibson reconsiders and redefines his relationships with his family, his friends, and with himself.
#  gibson bonifacio stopped speaking as a child. he is now twenty years old, returning to manila from his studies abroad, his first visit home in three years. he finds his family trying to keep it together, his mother still hurting from a tragic loss in the past. in the backdrop of the vibrant local music scene, his childhood best friend reaches out to him, and he finds a chance at his first real romantic relationship. amidst the holidays, gibson reconsiders and redefines his relationships with his family, his friends, and with himself.
# ['gibson', 'bonifacio', 'stopped', 'speaking', 'child', 'now', 'twenty', 'years', 'old', 'returning', 'manila', 'from', 'his', 'studies', 'abroad', 'his', 'first', 'visit', 'home', 'three', 'years', 'finds', 'his', 'family', 'trying', 'keep', 'together', 'his', 'mother', 'still', 'hurting', 'from', 'tragic', 'loss', 'the', 'past', 'the', 'backdrop', 'the', 'vibrant', 'local', 'music', 'scene', 'his', 'childhood', 'best', 'friend', 'reaches', 'out', 'him', 'and', 'finds', 'chance', 'his', 'first', 'real', 'romantic', 'relationship', 'amidst', 'the', 'holidays', 'gibson', 'reconsiders', 'and', 'redefines', 'his', 'relationships', 'with', 'his', 'family', 'his', 'friends', 'and', 'with', 'himself']
# ['gibson', 'bonifacio', 'stopped', 'speaking', 'child', 'twenty', 'years', 'old', 'returning', 'manila', 'studies', 'abroad', 'first', 'visit', 'home', 'three', 'years', 'finds', 'family', 'trying', 'keep', 'together', 'mother', 'still', 'hurting', 'tragic', 'loss', 'past', 'backdrop', 'vibrant', 'local', 'music', 'scene', 'childhood', 'best', 'friend', 'reaches', 'finds', 'chance', 'first', 'real', 'romantic', 'relationship', 'amidst', 'holidays', 'gibson', 'reconsiders', 'redefines', 'relationships', 'family', 'friends']
#  Krotoa [her Khoi name] was a Khoi girl (c.1643-1674) of the Goringhaicona tribe from the Cape who was taken at the impressionable age of ten or eleven years old into the home of Jan van Riebeeck as a domestic servant. When the young Krotoa moved into the home of Jan van Riebeeck, she became a 'pet' project to his wife, Maria. A tragic heroine - Krotoa: Eva of the Cape. The only recorded female interpreter of her time, was the bridge between the Khoi people and the Dutch settlers. She aided Jan van Riebeeck in his dealings with the Khoi and was instrumental in negotiating the end of the first Dutch-Khoi war. We examine the life of a woman now known as the Mother of the Afrikaaner Nation. Krotoa was directed by Kaye Ann Williams with Uwe Jansch as Director of Photography and producer by Roberta Durrant.
#  krotoa [her khoi name] was a khoi girl (c.1643-1674) of the goringhaicona tribe from the cape who was taken at the impressionable age of ten or eleven years old into the home of jan van riebeeck as a domestic servant. when the young krotoa moved into the home of jan van riebeeck, she became a 'pet' project to his wife, maria. a tragic heroine - krotoa: eva of the cape. the only recorded female interpreter of her time, was the bridge between the khoi people and the dutch settlers. she aided jan van riebeeck in his dealings with the khoi and was instrumental in negotiating the end of the first dutch-khoi war. we examine the life of a woman now known as the mother of the afrikaaner nation. krotoa was directed by kaye ann williams with uwe jansch as director of photography and producer by roberta durrant.
# ['krotoa', 'her', 'khoi', 'name', 'was', 'khoi', 'girl', '1643', '1674', 'the', 'goringhaicona', 'tribe', 'from', 'the', 'cape', 'who', 'was', 'taken', 'the', 'impressionable', 'age', 'ten', 'eleven', 'years', 'old', 'into', 'the', 'home', 'jan', 'van', 'riebeeck', 'domestic', 'servant', 'when', 'the', 'young', 'krotoa', 'moved', 'into', 'the', 'home', 'jan', 'van', 'riebeeck', 'she', 'became', 'pet', 'project', 'his', 'wife', 'maria', 'tragic', 'heroine', 'krotoa', 'eva', 'the', 'cape', 'the', 'only', 'recorded', 'female', 'interpreter', 'her', 'time', 'was', 'the', 'bridge', 'between', 'the', 'khoi', 'people', 'and', 'the', 'dutch', 'settlers', 'she', 'aided', 'jan', 'van', 'riebeeck', 'his', 'dealings', 'with', 'the', 'khoi', 'and', 'was', 'instrumental', 'negotiating', 'the', 'end', 'the', 'first', 'dutch', 'khoi', 'war', 'examine', 'the', 'life', 'woman', 'now', 'known', 'the', 'mother', 'the', 'afrikaaner', 'nation', 'krotoa', 'was', 'directed', 'kaye', 'ann', 'williams', 'with', 'uwe', 'jansch', 'director', 'photography', 'and', 'producer', 'roberta', 'durrant']
# ['krotoa', 'khoi', 'name', 'khoi', 'girl', '1643', '1674', 'goringhaicona', 'tribe', 'cape', 'taken', 'impressionable', 'age', 'ten', 'eleven', 'years', 'old', 'home', 'jan', 'van', 'riebeeck', 'domestic', 'servant', 'young', 'krotoa', 'moved', 'home', 'jan', 'van', 'riebeeck', 'became', 'pet', 'project', 'wife', 'maria', 'tragic', 'heroine', 'krotoa', 'eva', 'cape', 'recorded', 'female', 'interpreter', 'time', 'bridge', 'khoi', 'people', 'dutch', 'settlers', 'aided', 'jan', 'van', 'riebeeck', 'dealings', 'khoi', 'instrumental', 'negotiating', 'end', 'first', 'dutch', 'khoi', 'war', 'examine', 'life', 'woman', 'known', 'mother', 'afrikaaner', 'nation', 'krotoa', 'directed', 'kaye', 'ann', 'williams', 'uwe', 'jansch', 'director', 'photography', 'producer', 'roberta', 'durrant']
#  When a terminally ill man, Anton Meers (François Van de Voorde) receives a strange train ticket, an exceptional journey is about to begin. With only one suitcase full of life experiences and memories, he boards a very special train intended solely for him. It is the beginning of a certain journey with an unknow destination. Knowing this is his final voyage in life, it's a journey filled with hope towards a new beginning at the other side of our existence.
#  when a terminally ill man, anton meers (françois van de voorde) receives a strange train ticket, an exceptional journey is about to begin. with only one suitcase full of life experiences and memories, he boards a very special train intended solely for him. it is the beginning of a certain journey with an unknow destination. knowing this is his final voyage in life, it's a journey filled with hope towards a new beginning at the other side of our existence.
# ['when', 'terminally', 'ill', 'man', 'anton', 'meers', 'françois', 'van', 'voorde', 'receives', 'strange', 'train', 'ticket', 'exceptional', 'journey', 'about', 'begin', 'with', 'only', 'one', 'suitcase', 'full', 'life', 'experiences', 'and', 'memories', 'boards', 'very', 'special', 'train', 'intended', 'solely', 'for', 'him', 'the', 'beginning', 'certain', 'journey', 'with', 'unknow', 'destination', 'knowing', 'this', 'his', 'final', 'voyage', 'life', 'journey', 'filled', 'with', 'hope', 'towards', 'new', 'beginning', 'the', 'other', 'side', 'our', 'existence']
# ['terminally', 'ill', 'man', 'anton', 'meers', 'françois', 'van', 'voorde', 'receives', 'strange', 'train', 'ticket', 'exceptional', 'journey', 'begin', 'one', 'suitcase', 'full', 'life', 'experiences', 'memories', 'boards', 'special', 'train', 'intended', 'solely', 'beginning', 'certain', 'journey', 'unknow', 'destination', 'knowing', 'final', 'voyage', 'life', 'journey', 'filled', 'hope', 'towards', 'new', 'beginning', 'side', 'existence']
#  A coffee machine, a platypus, a star and we humans are made of the same raw materials: atoms. If everything is made of the same matter, then what is the difference between living things and non-living things? What is it that distinguishes us from a wardrobe or Mount Fuji if our nature is purely chemical?
#  a coffee machine, a platypus, a star and we humans are made of the same raw materials: atoms. if everything is made of the same matter, then what is the difference between living things and non-living things? what is it that distinguishes us from a wardrobe or mount fuji if our nature is purely chemical?
# ['coffee', 'machine', 'platypus', 'star', 'and', 'humans', 'are', 'made', 'the', 'same', 'raw', 'materials', 'atoms', 'everything', 'made', 'the', 'same', 'matter', 'then', 'what', 'the', 'difference', 'between', 'living', 'things', 'and', 'non', 'living', 'things', 'what', 'that', 'distinguishes', 'from', 'wardrobe', 'mount', 'fuji', 'our', 'nature', 'purely', 'chemical']
# ['coffee', 'machine', 'platypus', 'star', 'humans', 'made', 'raw', 'materials', 'atoms', 'everything', 'made', 'matter', 'difference', 'living', 'things', 'non', 'living', 'things', 'distinguishes', 'wardrobe', 'mount', 'fuji', 'nature', 'purely', 'chemical']
#  Jack Lawrence was just a normal police officer. Until one day his barely legal daughter was taken by the sorcerer, Keenan cuntmuncher. Now Jack must embark on a quest with the help of his companions, dicky and titty, to save the poon of his beloved daughter before that poon becomes worn out.
#  jack lawrence was just a normal police officer. until one day his barely legal daughter was taken by the sorcerer, keenan cuntmuncher. now jack must embark on a quest with the help of his companions, dicky and titty, to save the poon of his beloved daughter before that poon becomes worn out.
# ['jack', 'lawrence', 'was', 'just', 'normal', 'police', 'officer', 'until', 'one', 'day', 'his', 'barely', 'legal', 'daughter', 'was', 'taken', 'the', 'sorcerer', 'keenan', 'cuntmuncher', 'now', 'jack', 'must', 'embark', 'quest', 'with', 'the', 'help', 'his', 'companions', 'dicky', 'and', 'titty', 'save', 'the', 'poon', 'his', 'beloved', 'daughter', 'before', 'that', 'poon', 'becomes', 'worn', 'out']
# ['jack', 'lawrence', 'normal', 'police', 'officer', 'one', 'day', 'barely', 'legal', 'daughter', 'taken', 'sorcerer', 'keenan', 'cuntmuncher', 'jack', 'must', 'embark', 'quest', 'help', 'companions', 'dicky', 'titty', 'save', 'poon', 'beloved', 'daughter', 'poon', 'becomes', 'worn']
#  Seen through the eyes of small, midsize and large Mexican maize producers, Sunu weaves together different stories from a threatened rural world. It journeys into the heart of a country where people encourage their determination to stay free, to work the land and cultivate its seeds, to be true to their cultures and spiritual ways, all in a modern world that at the same time both needs them and disdains them
#  seen through the eyes of small, midsize and large mexican maize producers, sunu weaves together different stories from a threatened rural world. it journeys into the heart of a country where people encourage their determination to stay free, to work the land and cultivate its seeds, to be true to their cultures and spiritual ways, all in a modern world that at the same time both needs them and disdains them
# ['seen', 'through', 'the', 'eyes', 'small', 'midsize', 'and', 'large', 'mexican', 'maize', 'producers', 'sunu', 'weaves', 'together', 'different', 'stories', 'from', 'threatened', 'rural', 'world', 'journeys', 'into', 'the', 'heart', 'country', 'where', 'people', 'encourage', 'their', 'determination', 'stay', 'free', 'work', 'the', 'land', 'and', 'cultivate', 'its', 'seeds', 'true', 'their', 'cultures', 'and', 'spiritual', 'ways', 'all', 'modern', 'world', 'that', 'the', 'same', 'time', 'both', 'needs', 'them', 'and', 'disdains', 'them']
# ['seen', 'eyes', 'small', 'midsize', 'large', 'mexican', 'maize', 'producers', 'sunu', 'weaves', 'together', 'different', 'stories', 'threatened', 'rural', 'world', 'journeys', 'heart', 'country', 'people', 'encourage', 'determination', 'stay', 'free', 'work', 'land', 'cultivate', 'seeds', 'true', 'cultures', 'spiritual', 'ways', 'modern', 'world', 'time', 'needs', 'disdains']
#  Spencer Wellington, a wealthy young man, who is threatened with paresis, will not take his physician's warning, and marries Grace Valient. Dr. Rand loves the same woman, but his professional honor will not permit him to tell her the secret about her husband. A child is born, a hopeless defective that dies almost immediately. The mother loses her mind for a time, and another child is substituted for the dead baby. In the meantime the husband keeps getting worse. Realizing that he cannot hold off the moment of his mental breakdown much longer, Wellington starts in on a fast round of debauchery. He keeps a number of dancing girls in a secret retreat on his estate, and one night falls dead in tin- middle of a wild carouse. Indications point to the union of Doctor Rand and the widow.
#  spencer wellington, a wealthy young man, who is threatened with paresis, will not take his physician's warning, and marries grace valient. dr. rand loves the same woman, but his professional honor will not permit him to tell her the secret about her husband. a child is born, a hopeless defective that dies almost immediately. the mother loses her mind for a time, and another child is substituted for the dead baby. in the meantime the husband keeps getting worse. realizing that he cannot hold off the moment of his mental breakdown much longer, wellington starts in on a fast round of debauchery. he keeps a number of dancing girls in a secret retreat on his estate, and one night falls dead in tin- middle of a wild carouse. indications point to the union of doctor rand and the widow.
# ['spencer', 'wellington', 'wealthy', 'young', 'man', 'who', 'threatened', 'with', 'paresis', 'will', 'not', 'take', 'his', 'physician', 'warning', 'and', 'marries', 'grace', 'valient', 'rand', 'loves', 'the', 'same', 'woman', 'but', 'his', 'professional', 'honor', 'will', 'not', 'permit', 'him', 'tell', 'her', 'the', 'secret', 'about', 'her', 'husband', 'child', 'born', 'hopeless', 'defective', 'that', 'dies', 'almost', 'immediately', 'the', 'mother', 'loses', 'her', 'mind', 'for', 'time', 'and', 'another', 'child', 'substituted', 'for', 'the', 'dead', 'baby', 'the', 'meantime', 'the', 'husband', 'keeps', 'getting', 'worse', 'realizing', 'that', 'cannot', 'hold', 'off', 'the', 'moment', 'his', 'mental', 'breakdown', 'much', 'longer', 'wellington', 'starts', 'fast', 'round', 'debauchery', 'keeps', 'number', 'dancing', 'girls', 'secret', 'retreat', 'his', 'estate', 'and', 'one', 'night', 'falls', 'dead', 'tin', 'middle', 'wild', 'carouse', 'indications', 'point', 'the', 'union', 'doctor', 'rand', 'and', 'the', 'widow']
# ['spencer', 'wellington', 'wealthy', 'young', 'man', 'threatened', 'paresis', 'take', 'physician', 'warning', 'marries', 'grace', 'valient', 'rand', 'loves', 'woman', 'professional', 'honor', 'permit', 'tell', 'secret', 'husband', 'child', 'born', 'hopeless', 'defective', 'dies', 'almost', 'immediately', 'mother', 'loses', 'mind', 'time', 'another', 'child', 'substituted', 'dead', 'baby', 'meantime', 'husband', 'keeps', 'getting', 'worse', 'realizing', 'cannot', 'hold', 'moment', 'mental', 'breakdown', 'much', 'longer', 'wellington', 'starts', 'fast', 'round', 'debauchery', 'keeps', 'number', 'dancing', 'girls', 'secret', 'retreat', 'estate', 'one', 'night', 'falls', 'dead', 'tin', 'middle', 'wild', 'carouse', 'indications', 'point', 'union', 'doctor', 'rand', 'widow']
#  Dean and Randy are best friends who yearn to be a part of something bigger than themselves. Despite their best efforts, attempts to connect land them flat on their faces as they struggle to grow into the guys they want to be.
#  dean and randy are best friends who yearn to be a part of something bigger than themselves. despite their best efforts, attempts to connect land them flat on their faces as they struggle to grow into the guys they want to be.
# ['dean', 'and', 'randy', 'are', 'best', 'friends', 'who', 'yearn', 'part', 'something', 'bigger', 'than', 'themselves', 'despite', 'their', 'best', 'efforts', 'attempts', 'connect', 'land', 'them', 'flat', 'their', 'faces', 'they', 'struggle', 'grow', 'into', 'the', 'guys', 'they', 'want']
# ['dean', 'randy', 'best', 'friends', 'yearn', 'part', 'something', 'bigger', 'despite', 'best', 'efforts', 'attempts', 'connect', 'land', 'flat', 'faces', 'struggle', 'grow', 'guys', 'want']
#  In the context of Australia's cold war a 'hidden history' of Melbourne's Realist film movement (1945-1959) is explored through the first person account of a filmmaker of another generation, speaking to the 'indy-media' movement of the present day.
#  in the context of australia's cold war a 'hidden history' of melbourne's realist film movement (1945-1959) is explored through the first person account of a filmmaker of another generation, speaking to the 'indy-media' movement of the present day.
# ['the', 'context', 'australia', 'cold', 'war', 'hidden', 'history', 'melbourne', 'realist', 'film', 'movement', '1945', '1959', 'explored', 'through', 'the', 'first', 'person', 'account', 'filmmaker', 'another', 'generation', 'speaking', 'the', 'indy', 'media', 'movement', 'the', 'present', 'day']
# ['context', 'australia', 'cold', 'war', 'hidden', 'history', 'melbourne', 'realist', 'film', 'movement', '1945', '1959', 'explored', 'first', 'person', 'account', 'filmmaker', 'another', 'generation', 'speaking', 'indy', 'media', 'movement', 'present', 'day']
#  Struggling hippie independent filmmaker Mick gets his big break after he finds out that his girlfriend Marlene's father Burt is a movie producer. Unbeknown to Mick, Burt only specializes in porno pictures. Mick cranks out a cruddy science fiction stinker in three days for Burt, who demands countless changes and has a hard time figuring out how to distribute Mick's lousy movie.
#  struggling hippie independent filmmaker mick gets his big break after he finds out that his girlfriend marlene's father burt is a movie producer. unbeknown to mick, burt only specializes in porno pictures. mick cranks out a cruddy science fiction stinker in three days for burt, who demands countless changes and has a hard time figuring out how to distribute mick's lousy movie.
# ['struggling', 'hippie', 'independent', 'filmmaker', 'mick', 'gets', 'his', 'big', 'break', 'after', 'finds', 'out', 'that', 'his', 'girlfriend', 'marlene', 'father', 'burt', 'movie', 'producer', 'unbeknown', 'mick', 'burt', 'only', 'specializes', 'porno', 'pictures', 'mick', 'cranks', 'out', 'cruddy', 'science', 'fiction', 'stinker', 'three', 'days', 'for', 'burt', 'who', 'demands', 'countless', 'changes', 'and', 'has', 'hard', 'time', 'figuring', 'out', 'how', 'distribute', 'mick', 'lousy', 'movie']
# ['struggling', 'hippie', 'independent', 'filmmaker', 'mick', 'gets', 'big', 'break', 'finds', 'girlfriend', 'marlene', 'father', 'burt', 'movie', 'producer', 'unbeknown', 'mick', 'burt', 'specializes', 'porno', 'pictures', 'mick', 'cranks', 'cruddy', 'science', 'fiction', 'stinker', 'three', 'days', 'burt', 'demands', 'countless', 'changes', 'hard', 'time', 'figuring', 'distribute', 'mick', 'lousy', 'movie']
#  Capital Culture - This web series features four characters, based on young, creative females living in Wellington, New Zealand. Lennon is a fashionista, a self proclaimed style setter running her own blog while working part time in a vintage clothing store on Cuba Street. Imogen is a hospitality guru - a mixologist who lives for inventing the next innovative cocktail working as a bartender in a well known Cuba Street hangout. Willoughby is a singer/song writer and aspiring DJ who works in a cafe to pay the bills but life revolves around getting the next 'gig'. Frankie is a film maker, a Toi Whakaari drop out who wants to work on her own film projects and every spare moment is a chance to network. Each scene takes a satirical look into their daily lives.
#  capital culture - this web series features four characters, based on young, creative females living in wellington, new zealand. lennon is a fashionista, a self proclaimed style setter running her own blog while working part time in a vintage clothing store on cuba street. imogen is a hospitality guru - a mixologist who lives for inventing the next innovative cocktail working as a bartender in a well known cuba street hangout. willoughby is a singer/song writer and aspiring dj who works in a cafe to pay the bills but life revolves around getting the next 'gig'. frankie is a film maker, a toi whakaari drop out who wants to work on her own film projects and every spare moment is a chance to network. each scene takes a satirical look into their daily lives.
# ['capital', 'culture', 'this', 'web', 'series', 'features', 'four', 'characters', 'based', 'young', 'creative', 'females', 'living', 'wellington', 'new', 'zealand', 'lennon', 'fashionista', 'self', 'proclaimed', 'style', 'setter', 'running', 'her', 'own', 'blog', 'while', 'working', 'part', 'time', 'vintage', 'clothing', 'store', 'cuba', 'street', 'imogen', 'hospitality', 'guru', 'mixologist', 'who', 'lives', 'for', 'inventing', 'the', 'next', 'innovative', 'cocktail', 'working', 'bartender', 'well', 'known', 'cuba', 'street', 'hangout', 'willoughby', 'singer', 'song', 'writer', 'and', 'aspiring', 'who', 'works', 'cafe', 'pay', 'the', 'bills', 'but', 'life', 'revolves', 'around', 'getting', 'the', 'next', 'gig', 'frankie', 'film', 'maker', 'toi', 'whakaari', 'drop', 'out', 'who', 'wants', 'work', 'her', 'own', 'film', 'projects', 'and', 'every', 'spare', 'moment', 'chance', 'network', 'each', 'scene', 'takes', 'satirical', 'look', 'into', 'their', 'daily', 'lives']
# ['capital', 'culture', 'web', 'series', 'features', 'four', 'characters', 'based', 'young', 'creative', 'females', 'living', 'wellington', 'new', 'zealand', 'lennon', 'fashionista', 'self', 'proclaimed', 'style', 'setter', 'running', 'blog', 'working', 'part', 'time', 'vintage', 'clothing', 'store', 'cuba', 'street', 'imogen', 'hospitality', 'guru', 'mixologist', 'lives', 'inventing', 'next', 'innovative', 'cocktail', 'working', 'bartender', 'well', 'known', 'cuba', 'street', 'hangout', 'willoughby', 'singer', 'song', 'writer', 'aspiring', 'works', 'cafe', 'pay', 'bills', 'life', 'revolves', 'around', 'getting', 'next', 'gig', 'frankie', 'film', 'maker', 'toi', 'whakaari', 'drop', 'wants', 'work', 'film', 'projects', 'every', 'spare', 'moment', 'chance', 'network', 'scene', 'takes', 'satirical', 'look', 'daily', 'lives']
#  Around a decade ago a group of artists banded together under the idea that a street that could be scary to walk down at night could be host to something new. Ten years later, we know it as Art Crawl, and once a month we're all there, on a street that has changed as much as the city has.
#  around a decade ago a group of artists banded together under the idea that a street that could be scary to walk down at night could be host to something new. ten years later, we know it as art crawl, and once a month we're all there, on a street that has changed as much as the city has.
# ['around', 'decade', 'ago', 'group', 'artists', 'banded', 'together', 'under', 'the', 'idea', 'that', 'street', 'that', 'could', 'scary', 'walk', 'down', 'night', 'could', 'host', 'something', 'new', 'ten', 'years', 'later', 'know', 'art', 'crawl', 'and', 'once', 'month', 'all', 'there', 'street', 'that', 'has', 'changed', 'much', 'the', 'city', 'has']
# ['around', 'decade', 'ago', 'group', 'artists', 'banded', 'together', 'idea', 'street', 'could', 'scary', 'walk', 'night', 'could', 'host', 'something', 'new', 'ten', 'years', 'later', 'know', 'art', 'crawl', 'month', 'street', 'changed', 'much', 'city']
#  DREAMING NICARAGUA is a film about HOPE. It's about love for the dignity and courage of the human spirit that, even immersed in uttermost tragic conditions, fights for a better life, and in this case, with a friendly SMILE. DREAMING is a sensitive and lyrical portrayal of four children living in extreme poverty in Nicaragua. The film takes us beyond their hardships and gives voice to the youngsters, who are surprisingly funny, hopeful, and optimistic. A traveling art teacher provides a safe arena for our four unlikely protagonists to express their innermost thoughts. When painting, the kids momentarily escape the stresses of their reality into a world of dreams and ideas, a stark contrast to their lives outside: a vicious cycle of hunger, child labor, and violence. Despite the extreme circumstances, the children and their families face their lives with an inspiring unity, strength and humor.
#  dreaming nicaragua is a film about hope. it's about love for the dignity and courage of the human spirit that, even immersed in uttermost tragic conditions, fights for a better life, and in this case, with a friendly smile. dreaming is a sensitive and lyrical portrayal of four children living in extreme poverty in nicaragua. the film takes us beyond their hardships and gives voice to the youngsters, who are surprisingly funny, hopeful, and optimistic. a traveling art teacher provides a safe arena for our four unlikely protagonists to express their innermost thoughts. when painting, the kids momentarily escape the stresses of their reality into a world of dreams and ideas, a stark contrast to their lives outside: a vicious cycle of hunger, child labor, and violence. despite the extreme circumstances, the children and their families face their lives with an inspiring unity, strength and humor.
# ['dreaming', 'nicaragua', 'film', 'about', 'hope', 'about', 'love', 'for', 'the', 'dignity', 'and', 'courage', 'the', 'human', 'spirit', 'that', 'even', 'immersed', 'uttermost', 'tragic', 'conditions', 'fights', 'for', 'better', 'life', 'and', 'this', 'case', 'with', 'friendly', 'smile', 'dreaming', 'sensitive', 'and', 'lyrical', 'portrayal', 'four', 'children', 'living', 'extreme', 'poverty', 'nicaragua', 'the', 'film', 'takes', 'beyond', 'their', 'hardships', 'and', 'gives', 'voice', 'the', 'youngsters', 'who', 'are', 'surprisingly', 'funny', 'hopeful', 'and', 'optimistic', 'traveling', 'art', 'teacher', 'provides', 'safe', 'arena', 'for', 'our', 'four', 'unlikely', 'protagonists', 'express', 'their', 'innermost', 'thoughts', 'when', 'painting', 'the', 'kids', 'momentarily', 'escape', 'the', 'stresses', 'their', 'reality', 'into', 'world', 'dreams', 'and', 'ideas', 'stark', 'contrast', 'their', 'lives', 'outside', 'vicious', 'cycle', 'hunger', 'child', 'labor', 'and', 'violence', 'despite', 'the', 'extreme', 'circumstances', 'the', 'children', 'and', 'their', 'families', 'face', 'their', 'lives', 'with', 'inspiring', 'unity', 'strength', 'and', 'humor']
# ['dreaming', 'nicaragua', 'film', 'hope', 'love', 'dignity', 'courage', 'human', 'spirit', 'even', 'immersed', 'uttermost', 'tragic', 'conditions', 'fights', 'better', 'life', 'case', 'friendly', 'smile', 'dreaming', 'sensitive', 'lyrical', 'portrayal', 'four', 'children', 'living', 'extreme', 'poverty', 'nicaragua', 'film', 'takes', 'beyond', 'hardships', 'gives', 'voice', 'youngsters', 'surprisingly', 'funny', 'hopeful', 'optimistic', 'traveling', 'art', 'teacher', 'provides', 'safe', 'arena', 'four', 'unlikely', 'protagonists', 'express', 'innermost', 'thoughts', 'painting', 'kids', 'momentarily', 'escape', 'stresses', 'reality', 'world', 'dreams', 'ideas', 'stark', 'contrast', 'lives', 'outside', 'vicious', 'cycle', 'hunger', 'child', 'labor', 'violence', 'despite', 'extreme', 'circumstances', 'children', 'families', 'face', 'lives', 'inspiring', 'unity', 'strength', 'humor']
#  In a pattern that many domestic sitcoms would follow over the next 15 years, the plotlines followed the exploits of zany Mary Kay. Her husband, Johnny, was a sane, sensible banker who had to rescue her from herself. (The Stearns were married in real life.) In December, 1948, Mary Kay gave birth to son Christopher. Because Mary Kay's pregnancy was hard to hide, his birth was incorporated into the show. Shortly after New Year's Day, 1949, Christopher was written into the show as a character. During shooting, he either lay in his bassinet or was held by one of the Stearns or Mary Kay's mother. Shot live in New York, where it was set. Sponsored by Anacin.
#  in a pattern that many domestic sitcoms would follow over the next 15 years, the plotlines followed the exploits of zany mary kay. her husband, johnny, was a sane, sensible banker who had to rescue her from herself. (the stearns were married in real life.) in december, 1948, mary kay gave birth to son christopher. because mary kay's pregnancy was hard to hide, his birth was incorporated into the show. shortly after new year's day, 1949, christopher was written into the show as a character. during shooting, he either lay in his bassinet or was held by one of the stearns or mary kay's mother. shot live in new york, where it was set. sponsored by anacin.
# ['pattern', 'that', 'many', 'domestic', 'sitcoms', 'would', 'follow', 'over', 'the', 'next', 'years', 'the', 'plotlines', 'followed', 'the', 'exploits', 'zany', 'mary', 'kay', 'her', 'husband', 'johnny', 'was', 'sane', 'sensible', 'banker', 'who', 'had', 'rescue', 'her', 'from', 'herself', 'the', 'stearns', 'were', 'married', 'real', 'life', 'december', '1948', 'mary', 'kay', 'gave', 'birth', 'son', 'christopher', 'because', 'mary', 'kay', 'pregnancy', 'was', 'hard', 'hide', 'his', 'birth', 'was', 'incorporated', 'into', 'the', 'show', 'shortly', 'after', 'new', 'year', 'day', '1949', 'christopher', 'was', 'written', 'into', 'the', 'show', 'character', 'during', 'shooting', 'either', 'lay', 'his', 'bassinet', 'was', 'held', 'one', 'the', 'stearns', 'mary', 'kay', 'mother', 'shot', 'live', 'new', 'york', 'where', 'was', 'set', 'sponsored', 'anacin']
# ['pattern', 'many', 'domestic', 'sitcoms', 'would', 'follow', 'next', 'years', 'plotlines', 'followed', 'exploits', 'zany', 'mary', 'kay', 'husband', 'johnny', 'sane', 'sensible', 'banker', 'rescue', 'stearns', 'married', 'real', 'life', 'december', '1948', 'mary', 'kay', 'gave', 'birth', 'son', 'christopher', 'mary', 'kay', 'pregnancy', 'hard', 'hide', 'birth', 'incorporated', 'show', 'shortly', 'new', 'year', 'day', '1949', 'christopher', 'written', 'show', 'character', 'shooting', 'either', 'lay', 'bassinet', 'held', 'one', 'stearns', 'mary', 'kay', 'mother', 'shot', 'live', 'new', 'york', 'set', 'sponsored', 'anacin']
#  There are few places on earth as intimately tied to historic feats of strength as the Highlands of Scotland. There are countless stories of local warriors and clansmen training for battle. Of castle bodyguards proving their strength by carrying heavy weights over long distances. An often cited tale dates back to the 11th century when King Malcolm III summoned his countrymen to compete in a foot race that would determine who would become his royal messenger. All over Scotland are remnants of these ancient tests of strength - lifting stones, formed over the centuries by wind and river erosion, each with its own history and local lore. A relative few still know about and seek out these ancient stones. This is their story.
#  there are few places on earth as intimately tied to historic feats of strength as the highlands of scotland. there are countless stories of local warriors and clansmen training for battle. of castle bodyguards proving their strength by carrying heavy weights over long distances. an often cited tale dates back to the 11th century when king malcolm iii summoned his countrymen to compete in a foot race that would determine who would become his royal messenger. all over scotland are remnants of these ancient tests of strength - lifting stones, formed over the centuries by wind and river erosion, each with its own history and local lore. a relative few still know about and seek out these ancient stones. this is their story.
# ['there', 'are', 'few', 'places', 'earth', 'intimately', 'tied', 'historic', 'feats', 'strength', 'the', 'highlands', 'scotland', 'there', 'are', 'countless', 'stories', 'local', 'warriors', 'and', 'clansmen', 'training', 'for', 'battle', 'castle', 'bodyguards', 'proving', 'their', 'strength', 'carrying', 'heavy', 'weights', 'over', 'long', 'distances', 'often', 'cited', 'tale', 'dates', 'back', 'the', '11th', 'century', 'when', 'king', 'malcolm', 'iii', 'summoned', 'his', 'countrymen', 'compete', 'foot', 'race', 'that', 'would', 'determine', 'who', 'would', 'become', 'his', 'royal', 'messenger', 'all', 'over', 'scotland', 'are', 'remnants', 'these', 'ancient', 'tests', 'strength', 'lifting', 'stones', 'formed', 'over', 'the', 'centuries', 'wind', 'and', 'river', 'erosion', 'each', 'with', 'its', 'own', 'history', 'and', 'local', 'lore', 'relative', 'few', 'still', 'know', 'about', 'and', 'seek', 'out', 'these', 'ancient', 'stones', 'this', 'their', 'story']
# ['places', 'earth', 'intimately', 'tied', 'historic', 'feats', 'strength', 'highlands', 'scotland', 'countless', 'stories', 'local', 'warriors', 'clansmen', 'training', 'battle', 'castle', 'bodyguards', 'proving', 'strength', 'carrying', 'heavy', 'weights', 'long', 'distances', 'often', 'cited', 'tale', 'dates', 'back', '11th', 'century', 'king', 'malcolm', 'iii', 'summoned', 'countrymen', 'compete', 'foot', 'race', 'would', 'determine', 'would', 'become', 'royal', 'messenger', 'scotland', 'remnants', 'ancient', 'tests', 'strength', 'lifting', 'stones', 'formed', 'centuries', 'wind', 'river', 'erosion', 'history', 'local', 'lore', 'relative', 'still', 'know', 'seek', 'ancient', 'stones', 'story']
# ...
#  her parents being zoologists, homeschooled cady heron lived in africa for 15 years. attending a chicago public high school for the first time, she starts out by befriending the "best people you will meet", janis, a supposedly lesbian girl; and damian, a boy "too gay to function". cady is warned to avoid the "worst people you will ever meet", the plastics--a clique comprised of three girls: gretchen wieners, a girl who's rich because her father invented toaster strudel; karen smith, the "dumbest girl you will ever meet"; and regina george, the unofficial leader and the meanest one. she becomes a hit with the plastics and eventually assimilates into the clique, only for janis to ask her sabotage them. after conflicts involving regina's ex-boyfriend, aaron samuels, cady later becomes tied between being part of them or sabotaging them. whilst eventually becoming one, she sabotages them. she tricks regina into eating fattening candy bars that she claims will make her skinny, tries to break her and samuel up, and tries to turn her fellow plastics, karen and gretchen against her. will she be caught? will she become too plastic and become the fourth plastic? cady heron, a home-schooled girl lives in africa whose parents are zoologist, now she, as a teenager, is in high school and decided to fit in. she fits in with the popular kids in high school, "the plastics", whom her friends wanted to forbid her from fitting in with them. she decided to hang out with regina george, a popular girl and her ex-boyfriend, aaron samuels. her parents being zoologists, cady heron has never known what "high school" truly meant. she lived her first 15 years in the african jungle, home-schooled, living life with only her parents and the animals of the wilderness, knowing all of the rules of survival. but when she leaves africa, she has to learn the rules of high school, which is a jugle in itsefe. it didn't take long before she met two sweet sweet teenagers, damian and janis. but in turns of high school they are known as the " out krowd." soon she meets the plastics, the three crude, beautiful, popular girls, consisting of regina, the unofficial leader, gretchen, who would do anything for regina, and karen, "one of the dumbest people you will ever meet." after just a few minuits they let her into their group, but cady wanted to keep her first friends, so she wasnt really sure. but damien and jannis thougt that it might be fun to play a game with the plastics so they concinded her to keep the relationship with the plastics. but only so thet could get to know all of there darkest secrets and then laugh at them. this doase not go really as they planed when candy falls in love with redigas ex boyfriend. when regina finds out, she seeks revenge of cady by taking aaron back. when cady finds out, what began as a game to discover secrets turns into a plan to destroy regina. now, cady, janis, and damian plot together to bring regina's status down. however, as cady spends more time with the plastics, she, too, begins to become one. cady heron moves to a new home from the bush country of africa. she goes to a new school where she meets janis and damian. her new friends warn her to stay away from the plastics: the a-list, popular, crude, and beautiful clique headed by regina george with gretchen and karen. when cady sees aaron samuels, she falls in love. when regina discovers this, she seeks revenge by taking and dangling aaron in front of cady. now cady, janis, and damian plot to bring regina's status down. however, as cady continues to spend more time with the plastics, she begins to become one of them. raised in the african bush country by her zoologist parents, cady heron thinks she knows all about the "survival of the fittest". but the law of the jungle takes on a whole new meaning when the home-schooled 16-year old enters public high school for the first time. trying to find her place between jocks, mathletes, and other subcultures, cady crosses paths with the  ...
# ['her', 'parents', 'being', 'zoologists', 'homeschooled', 'cady', 'heron', 'lived', 'africa', 'for', 'years', 'attending', 'chicago', 'public', 'high', 'school', 'for', 'the', 'first', 'time', 'she', 'starts', 'out', 'befriending', 'the', 'best', 'people', 'you', 'will', 'meet', 'janis', 'supposedly', 'lesbian', 'girl', 'and', 'damian', 'boy', 'too', 'gay', 'function', 'cady', 'warned', 'avoid', 'the', 'worst', 'people', 'you', 'will', 'ever', 'meet', 'the', 'plastics', 'clique', 'comprised', 'three', 'girls', 'gretchen', 'wieners', 'girl', 'who', 'rich', 'because', 'her', 'father', 'invented', 'toaster', 'strudel', 'karen', 'smith', 'the', 'dumbest', 'girl', 'you', 'will', 'ever', 'meet', 'and', 'regina', 'george', 'the', 'unofficial', 'leader', 'and', 'the', 'meanest', 'one', 'she', 'becomes', 'hit', 'with', 'the', 'plastics', 'and', 'eventually', 'assimilates', 'into', 'the', 'clique', 'only', 'for', 'janis', 'ask', 'her', 'sabotage', 'them', 'after', 'conflicts', 'involving', 'regina', 'boyfriend', 'aaron', 'samuels', 'cady', 'later', 'becomes', 'tied', 'between', 'being', 'part', 'them', 'sabotaging', 'them', 'whilst', 'eventually', 'becoming', 'one', 'she', 'sabotages', 'them', 'she', 'tricks', 'regina', 'into', 'eating', 'fattening', 'candy', 'bars', 'that', 'she', 'claims', 'will', 'make', 'her', 'skinny', 'tries', 'break', 'her', 'and', 'samuel', 'and', 'tries', 'turn', 'her', 'fellow', 'plastics', 'karen', 'and', 'gretchen', 'against', 'her', 'will', 'she', 'caught', 'will', 'she', 'become', 'too', 'plastic', 'and', 'become', 'the', 'fourth', 'plastic', 'cady', 'heron', 'home', 'schooled', 'girl', 'lives', 'africa', 'whose', 'parents', 'are', 'zoologist', 'now', 'she', 'teenager', 'high', 'school', 'and', 'decided', 'fit', 'she', 'fits', 'with', 'the', 'popular', 'kids', 'high', 'school', 'the', 'plastics', 'whom', 'her', 'friends', 'wanted', 'forbid', 'her', 'from', 'fitting', 'with', 'them', 'she', 'decided', 'hang', 'out', 'with', 'regina', 'george', 'popular', 'girl', 'and', 'her', 'boyfriend', 'aaron', 'samuels', 'her', 'parents', 'being', 'zoologists', 'cady', 'heron', 'has', 'never', 'known', 'what', 'high', 'school', 'truly', 'meant', 'she', 'lived', 'her', 'first', 'years', 'the', 'african', 'jungle', 'home', 'schooled', 'living', 'life', 'with', 'only', 'her', 'parents', 'and', 'the', 'animals', 'the', 'wilderness', 'knowing', 'all', 'the', 'rules', 'survival', 'but', 'when', 'she', 'leaves', 'africa', 'she', 'has', 'learn', 'the', 'rules', 'high', 'school', 'which', 'jugle', 'itsefe', 'didn', 'take', 'long', 'before', 'she', 'met', 'two', 'sweet', 'sweet', 'teenagers', 'damian', 'and', 'janis', 'but', 'turns', 'high', 'school', 'they', 'are', 'known', 'the', 'out', 'krowd', 'soon', 'she', 'meets', 'the', 'plastics', 'the', 'three', 'crude', 'beautiful', 'popular', 'girls', 'consisting', 'regina', 'the', 'unofficial', 'leader', 'gretchen', 'who', 'would', 'anything', 'for', 'regina', 'and', 'karen', 'one', 'the', 'dumbest', 'people', 'you', 'will', 'ever', 'meet', 'after', 'just', 'few', 'minuits', 'they', 'let', 'her', 'into', 'their', 'group', 'but', 'cady', 'wanted', 'keep', 'her', 'first', 'friends', 'she', 'wasnt', 'really', 'sure', 'but', 'damien', 'and', 'jannis', 'thougt', 'that', 'might', 'fun', 'play', 'game', 'with', 'the', 'plastics', 'they', 'concinded', 'her', 'keep', 'the', 'relationship', 'with', 'the', 'plastics', 'but', 'only', 'thet', 'could', 'get', 'know', 'all', 'there', 'darkest', 'secrets', 'and', 'then', 'laugh', 'them', 'this', 'doase', 'not', 'really', 'they', 'planed', 'when', 'candy', 'falls', 'love', 'with', 'redigas', 'boyfriend', 'when', 'regina', 'finds', 'out', 'she', 'seeks', 'revenge', 'cady', 'taking', 'aaron', 'back', 'when', 'cady', 'finds', 'out', 'what', 'began', 'game', 'discover', 'secrets', 'turns', 'into', 'plan', 'destroy', 'regina', 'now', 'cady', 'janis', 'and', 'damian', 'plot', 'together', 'bring', 'regina', 'status', 'down', 'however', 'cady', 'spends', 'mo ...
# ['parents', 'zoologists', 'homeschooled', 'cady', 'heron', 'lived', 'africa', 'years', 'attending', 'chicago', 'public', 'high', 'school', 'first', 'time', 'starts', 'befriending', 'best', 'people', 'meet', 'janis', 'supposedly', 'lesbian', 'girl', 'damian', 'boy', 'gay', 'function', 'cady', 'warned', 'avoid', 'worst', 'people', 'ever', 'meet', 'plastics', 'clique', 'comprised', 'three', 'girls', 'gretchen', 'wieners', 'girl', 'rich', 'father', 'invented', 'toaster', 'strudel', 'karen', 'smith', 'dumbest', 'girl', 'ever', 'meet', 'regina', 'george', 'unofficial', 'leader', 'meanest', 'one', 'becomes', 'hit', 'plastics', 'eventually', 'assimilates', 'clique', 'janis', 'ask', 'sabotage', 'conflicts', 'involving', 'regina', 'boyfriend', 'aaron', 'samuels', 'cady', 'later', 'becomes', 'tied', 'part', 'sabotaging', 'whilst', 'eventually', 'becoming', 'one', 'sabotages', 'tricks', 'regina', 'eating', 'fattening', 'candy', 'bars', 'claims', 'make', 'skinny', 'tries', 'break', 'samuel', 'tries', 'turn', 'fellow', 'plastics', 'karen', 'gretchen', 'caught', 'become', 'plastic', 'become', 'fourth', 'plastic', 'cady', 'heron', 'home', 'schooled', 'girl', 'lives', 'africa', 'whose', 'parents', 'zoologist', 'teenager', 'high', 'school', 'decided', 'fit', 'fits', 'popular', 'kids', 'high', 'school', 'plastics', 'friends', 'wanted', 'forbid', 'fitting', 'decided', 'hang', 'regina', 'george', 'popular', 'girl', 'boyfriend', 'aaron', 'samuels', 'parents', 'zoologists', 'cady', 'heron', 'never', 'known', 'high', 'school', 'truly', 'meant', 'lived', 'first', 'years', 'african', 'jungle', 'home', 'schooled', 'living', 'life', 'parents', 'animals', 'wilderness', 'knowing', 'rules', 'survival', 'leaves', 'africa', 'learn', 'rules', 'high', 'school', 'jugle', 'itsefe', 'take', 'long', 'met', 'two', 'sweet', 'sweet', 'teenagers', 'damian', 'janis', 'turns', 'high', 'school', 'known', 'krowd', 'soon', 'meets', 'plastics', 'three', 'crude', 'beautiful', 'popular', 'girls', 'consisting', 'regina', 'unofficial', 'leader', 'gretchen', 'would', 'anything', 'regina', 'karen', 'one', 'dumbest', 'people', 'ever', 'meet', 'minuits', 'let', 'group', 'cady', 'wanted', 'keep', 'first', 'friends', 'wasnt', 'really', 'sure', 'damien', 'jannis', 'thougt', 'might', 'fun', 'play', 'game', 'plastics', 'concinded', 'keep', 'relationship', 'plastics', 'thet', 'could', 'get', 'know', 'darkest', 'secrets', 'laugh', 'doase', 'really', 'planed', 'candy', 'falls', 'love', 'redigas', 'boyfriend', 'regina', 'finds', 'seeks', 'revenge', 'cady', 'taking', 'aaron', 'back', 'cady', 'finds', 'began', 'game', 'discover', 'secrets', 'turns', 'plan', 'destroy', 'regina', 'cady', 'janis', 'damian', 'plot', 'together', 'bring', 'regina', 'status', 'however', 'cady', 'spends', 'time', 'plastics', 'begins', 'become', 'one', 'cady', 'heron', 'moves', 'new', 'home', 'bush', 'country', 'africa', 'goes', 'new', 'school', 'meets', 'janis', 'damian', 'new', 'friends', 'warn', 'stay', 'away', 'plastics', 'list', 'popular', 'crude', 'beautiful', 'clique', 'headed', 'regina', 'george', 'gretchen', 'karen', 'cady', 'sees', 'aaron', 'samuels', 'falls', 'love', 'regina', 'discovers', 'seeks', 'revenge', 'taking', 'dangling', 'aaron', 'front', 'cady', 'cady', 'janis', 'damian', 'plot', 'bring', 'regina', 'status', 'however', 'cady', 'continues', 'spend', 'time', 'plastics', 'begins', 'become', 'one', 'raised', 'african', 'bush', 'country', 'zoologist', 'parents', 'cady', 'heron', 'thinks', 'knows', 'survival', 'fittest', 'law', 'jungle', 'takes', 'whole', 'new', 'meaning', 'home', 'schooled', 'year', 'old', 'enters', 'public', 'high', 'school', 'first', 'time', 'trying', 'find', 'place', 'jocks', 'mathletes', 'subcultures', 'cady', 'crosses', 'paths', 'meanest', 'species', 'queen', 'bee', 'aka', 'cool', 'calculating', 'regina', 'george', 'leader', 'school', 'fashionable', 'clique', 'plastics', 'cady', 'falls', 'regina', 'boyfriend', 'aaron', 'samuels', 'though', 'queen', 'bee', 'stung', 'schemes', 'dest ...
#  (French with English subtitles) In this study of the lust for youth, Michel, a disillusioned cop nearing retirement, becomes obsessed with the body of a beautiful woman he meets on the beach. His search for an unattainable love drives him deeper into darkness.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Run this cell without changes
data["preprocessed_text"] = text_data
data
# Out:
#          id                                           title          genre  \
# 789   31370                         Do You Believe? (2007)    documentary
# 2507  25529               The House That Jack Broke (2013)          drama
# 2376   5405                       Children of Peace (2016)    documentary
# 1378  49949                             Hwioribaram (2009)          drama
# 598   21445   Gui pian wang zhi zai xian xiong bang (1999)         horror
# ...     ...                                             ...            ...
# 4276  21962                     Phool Bane Angaarey (1991)         action
# 1528  25102                         The Journey (2016/III)          drama
# 4259  41715                Rainbow Over the Rockies (1947)        western
# 3686  31276     Figner: The End of a Silent Century (2006)          drama
# 1372  21990                      Buona come il pane (1981)         comedy
#
#                                                    desc  \
# 789    Do you believe?" digs deep into our spiritual...
# 2507   Early one morning, two FBI agents, Portman an...
# 2376   The Bosnian War was an international armed co...
# 1378   During winter vacation of their sophomore yea...
# 598    At a Hong Kong dormitory, the cook's little g...
# ...                                                 ...
# 4276   Dutta babu is standing for elections against ...
# 1528   In 2006, Northern Ireland's bloody Troubles h...
# 4259   Driving a herd of cattle to market, Jimmy fin...
# 3686   A story about the almost unknown soviet cinem...
# 1372   Lisette (Carmen Russo) is a high-priced call-...
#
#                                       preprocessed_text
# 789   [believ, dig, deep, spiritu, live, search, ans...
# 2507  [earli, one, morn, two, fbi, agent, portman, c...
# 2376  [bosnian, war, intern, arm, conflict, took, pl...
# 1378  [winter, vacat, sophomor, year, high, school, ...
# 598   [hong, kong, dormitori, cook, littl, granddaug...
# ...                                                 ...
# 4276  [dutta, babu, stand, elect, cun, corrupt, esta...
# 1528  [2006, northern, ireland, bloodi, troubl, drag...
# 4259  [drive, herd, cattl, market, jimmi, find, trai...
# 3686  [stori, almost, unknown, soviet, cinema, eye, ...
# 1372  [lisett, carmen, russo, high, price, call, gir...
#
# [1500 rows x 5 columns]

# %% [markdown]
# Now let's take a look at the top ten most frequent words for each genre.

# %%
# Run this cell without changes
import matplotlib.pyplot as plt
import seaborn as sns

# Set up figure and axes
fig, axes = plt.subplots(nrows=7, figsize=(12, 12))

# Empty dict to hold words that have already been plotted and their colors
plotted_words_and_colors = {}
# Establish color palette to pull from
# (If you get an error message about popping from an empty list, increase this #)
color_palette = sns.color_palette('cividis', n_colors=38)

# Creating a plot for each unique genre
data_by_genre = [y for _, y in data.groupby('genre', as_index=False)]
for idx, genre_df in enumerate(data_by_genre):
    # Find top 10 words in this genre
    all_words_in_genre = genre_df.preprocessed_text.explode()
    top_10 = all_words_in_genre.value_counts()[:10]
    
    # Select appropriate colors, reusing colors if words repeat
    colors = []
    for word in top_10.index:
        if word not in plotted_words_and_colors:
            new_color = color_palette.pop(0)
            plotted_words_and_colors[word] = new_color
        colors.append(plotted_words_and_colors[word])
    
    # Select axes, plot data, set title
    ax = axes[idx]
    ax.bar(top_10.index, top_10.values, color=colors)
    ax.set_title(genre_df.iloc[0].genre.title())
    
fig.tight_layout()

# %% [markdown]
# ## 3) Fit a Count Vectorizer
#
# Now that we have explored the data some, let's prepare it for modeling.
#
# Before we fit a vectorizer to the data, we need to convert the list of tokens for each document back to a string datatype and create a train test split.

# %%
# Run this cell without changes
from sklearn.model_selection import train_test_split

# Convert token lists to strings
data["joined_preprocessed_text"] = data["preprocessed_text"].str.join(" ")

# Create train test split
X_train, X_test, y_train, y_test = train_test_split(
    data["joined_preprocessed_text"], data.genre, test_size=0.3, random_state=2021)

X_train
# Out:
# 3806    young man aunt refus give inherit marri pass w...
# 3202    21st centuri seem one inexhaust wealth great c...
# 1886                                detail plot kept wrap
# 2674    walk dark live struggl refuge live krisan refu...
# 4176    dean randi best friend yearn part someth bigge...
#                               ...
# 3618    limpan alcohol put caretak home alcohol promis...
# 1412    escap ugli life alcohol mother uneduc barman s...
# 3413    discourag card life felt hank jim belushi man ...
# 3269    disown clair featur length independ comedi cla...
# 3734    stori depict problem bulli intimid junior stud...
# Name: joined_preprocessed_text, Length: 1050, dtype: object

# %% [markdown]
# **In the cell below, create a CountVectorizer instance ([documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html)) with default arguments, called `vectorizer`, and fit it to the training data.**

# %%
# CodeGrade step3
# Import the CountVectorizer object from sklearn

from sklearn.feature_extraction.text import CountVectorizer

# Create a `vectorizer` instance
vectorizer = CountVectorizer()

# Fit the vectorizer to the training data
vectorizer.fit(X_train)
# Out:
# CountVectorizer()

# %%
assert vectorizer

# %% [markdown]
# ## 4) Vectorize the Data
#
# In the cell below, vectorize the training and test datasets using the fitted count vectorizer.

# %%
# CodeGrade step4
# Replace None with appropriate code

X_train_vectorized = 
X_test_vectorized = None

# %%
from scipy.sparse.csr import csr_matrix
assert type(X_train_vectorized) == csr_matrix
assert type(X_test_vectorized) == csr_matrix

# %% [markdown]
# ## 5) Fit a Decision Tree Model
#
# In the cell below,
#
# - Create an instance of `sklearn`'s `DecisionTreeClassifier` ([documentation here](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)), using default arguments, with the variable name `dt`
# - Fit the model to the vectorized training data

# %%
# CodeGrade step5
# Replace None with appropriate code

# Import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier

# Initialize `dt`
dt = DecisionTreeClassifier()

# Fit the model to the training data
dt.fit(model)

# %%
assert dt

# %% [markdown]
# The following code will now evaluate our model on the test data:

# %%
# Run this cell without changes

from sklearn.metrics import plot_confusion_matrix
fig, ax = plt.subplots(figsize=(12,12))
plot_confusion_matrix(dt, X_test_vectorized, y_test, ax=ax, cmap="cividis");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-c009b180898d> in <module>
#       3 from sklearn.metrics import plot_confusion_matrix
#       4 fig, ax = plt.subplots(figsize=(12,12))
# ----> 5 plot_confusion_matrix(dt, X_test_vectorized, y_test, ax=ax, cmap="cividis");
#
# NameError: name 'dt' is not defined
